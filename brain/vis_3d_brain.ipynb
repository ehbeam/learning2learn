# %%
import matplotlib.pyplot as plt
from matplotlib.colors import to_hex
from collections import OrderedDict
from sklearn.preprocessing import binarize
from lib.utilities import *

# %%
dtm = pd.read_csv("data/dtm.csv.gz", compression="gzip", index_col=0)
activations = load_activations("thres0")

# %%
def score_lists(lists, dtm, constructs):
    dtm = pd.DataFrame(binarize(dtm, threshold=0),
                   index=dtm.index, columns=dtm.columns)
    con_counts = pd.DataFrame(index=dtm.index, columns=constructs)
    for construct in con_counts.columns:
        tkns = lists.loc[lists["CONSTRUCT"] == construct, "TOKEN"]
        tkns = [token for token in tkns if token in dtm.columns]
        con_counts[construct] = dtm[tkns].sum(axis=1)
    return(con_counts)

# %%
lists = pd.read_csv("results/lists_rdoc.csv", index_col=None)
constructs = OrderedDict.fromkeys(lists["CONSTRUCT"])
list_counts = score_lists(lists, dtm, constructs)

# %%
R = correlate(activations, list_counts, p_thres=1e-6)

# %%
R_max = max([np.max(np.max(R)), abs(np.min(np.min(R)))])

# %%
R_vals = sorted(R.values.ravel())

# %%
below_zero = R_vals.index(0) - 1
above_zero = len(R_vals) - (R_vals.index(0) + R_vals.count(0))

# %%
if below_zero < above_zero:
    R_vals = [-1 * max(R_vals)] * (above_zero - below_zero) + R_vals
# elif below_zero > above_zero:
#     R_vals = R_vals + [1] * (below_zero - above_zero)
len(R_vals)
# Out:
# 5734

# %%
R_vals = [n for n in R_vals if n != 0]
R_vals += [0]
R_vals = sorted(R_vals)

# %%
R_norm = [1-((max(R_vals)-x)/(max(R_vals)-min(R_vals))) for x in R_vals]

# %%
raw = plt.cm.coolwarm(R_norm)
palette_rgb, palette_hex = [], []
for hsv in raw:
    palette_rgb.append([round(n, 3) for n in hsv][:3])
    palette_hex.append(to_hex(hsv)[1:])

# %%
val2rgb = {R_vals[i]: palette_rgb[i] for i in range(len(R_vals))}
val2hex = {R_vals[i]: palette_hex[i] for i in range(len(R_vals))}

# %%
val2hex
# Out:
# {-0.2583978092884931: '3b4cc0',
#  -0.12676415348936476: '8fb1fe',
#  -0.11257254249320048: '98b9ff',
#  -0.11133457655870853: '98b9ff',
#  -0.10881549682025098: '9bbcff',
#  -0.10527796557578256: '9dbdff',
#  -0.10447295018237678: '9ebeff',
#  -0.09974841280200232: 'a1c0ff',
#  -0.09887175648743105: 'a2c1ff',
#  -0.09761174408585775: 'a2c1ff',
#  -0.0968362326360081: 'a3c2fe',
#  -0.09608619557688898: 'a3c2fe',
#  -0.09605604450645165: 'a3c2fe',
#  -0.09556613108173916: 'a3c2fe',
#  -0.09549356319251377: 'a3c2fe',
#  -0.094046696302377: 'a5c3fe',
#  -0.0906676358773578: 'a7c5fe',
#  -0.08906486492317768: 'a7c5fe',
#  -0.08532919735890988: 'aac7fd',
#  -0.0847046235487649: 'abc8fd',
#  -0.08372428767847515: 'abc8fd',
#  -0.0828860122810179: 'abc8fd',
#  -0.08284681848601586: 'abc8fd',
#  -0.08158569654387418: 'adc9fd',
#  -0.08086346381199326: 'adc9fd',
#  -0.08084722268812988: 'adc9fd',
#  -0.07958801231414767: 'aec9fc',
#  -0.07939854882886598: 'aec9fc',
#  -0.07800038496636427: 'afcafc',
#  -0.07715403962311301: 'afcafc',
#  -0.07684501837063724: 'afcafc',
#  -0.07672326775845623: 'afcafc',
#  -0.0766182703226424: 'b1cbfc',
#  -0.07657580188165018: 'b1cbfc',
#  -0.07629038031827651: 'b1cbfc',
#  -0.07589685563481045: 'b1cbfc',
#  -0.07559825269045335: 'b1cbfc',
#  -0.07429433789390331: 'b2ccfb',
#  -0.07424230684900394: 'b2ccfb',
#  -0.07420276857315292: 'b2ccfb',
#  -0.07366877361145455: 'b2ccfb',
#  -0.07329455702753458: 'b2ccfb',
#  -0.07288001271007913: 'b2ccfb',
#  -0.07264071356958646: 'b3cdfb',
#  -0.07251627159349819: 'b3cdfb',
#  -0.07229926261446873: 'b3cdfb',
#  -0.07221814942477846: 'b3cdfb',
#  -0.0715802807838673: 'b3cdfb',
#  -0.07154077553000307: 'b3cdfb',
#  -0.07078715819979162: 'b3cdfb',
#  -0.07044487502802672: 'b5cdfa',
#  -0.07043931868346923: 'b5cdfa',
#  -0.07039160552596938: 'b5cdfa',
#  -0.07001110883679909: 'b5cdfa',
#  -0.06990341416433576: 'b5cdfa',
#  -0.06966305173088315: 'b5cdfa',
#  -0.06951886394100487: 'b5cdfa',
#  -0.06948484038654044: 'b5cdfa',
#  -0.06945403369274274: 'b5cdfa',
#  -0.06922277217160677: 'b5cdfa',
#  -0.06918172888063935: 'b5cdfa',
#  -0.06868664169238137: 'b5cdfa',
#  -0.0685775027718284: 'b6cefa',
#  -0.06827641614038171: 'b6cefa',
#  -0.06804516212031322: 'b6cefa',
#  -0.06798662995028906: 'b6cefa',
#  -0.06785319201198144: 'b6cefa',
#  -0.06780082642504465: 'b6cefa',
#  -0.06767329351844356: 'b6cefa',
#  -0.06752640343871516: 'b6cefa',
#  -0.06717121203492658: 'b6cefa',
#  -0.06696876404081031: 'b6cefa',
#  -0.06675240599401872: 'b6cefa',
#  -0.06632637702450013: 'b7cff9',
#  -0.066229288277697: 'b7cff9',
#  -0.06594690767390655: 'b7cff9',
#  -0.06573536749049158: 'b7cff9',
#  -0.0654989971925562: 'b7cff9',
#  -0.06492190676552378: 'b7cff9',
#  -0.06490803350212399: 'b7cff9',
#  -0.0646758904683253: 'b7cff9',
#  -0.0642222868462516: 'b9d0f9',
#  -0.06395649904143018: 'b9d0f9',
#  -0.06392513468682194: 'b9d0f9',
#  -0.06360081833883596: 'b9d0f9',
#  -0.0635057683280997: 'b9d0f9',
#  -0.06337138175765819: 'b9d0f9',
#  -0.06319965117965216: 'b9d0f9',
#  -0.06304467184671396: 'b9d0f9',
#  -0.06291990372180174: 'b9d0f9',
#  -0.06283595856136061: 'b9d0f9',
#  -0.06279976465906116: 'b9d0f9',
#  -0.0625412581309099: 'bad0f8',
#  -0.06252862591730639: 'bad0f8',
#  -0.06215663569372712: 'bad0f8',
#  -0.06199527374689412: 'bad0f8',
#  -0.0618499969627889: 'bad0f8',
#  -0.061760282806778984: 'bad0f8',
#  -0.06168851750690702: 'bad0f8',
#  -0.061612221562690014: 'bad0f8',
#  -0.0614275798861708: 'bad0f8',
#  -0.061387351319432425: 'bad0f8',
#  -0.061165971809763714: 'bad0f8',
#  -0.061065566063080105: 'bad0f8',
#  -0.06096630903652982: 'bad0f8',
#  -0.06096072538227785: 'bad0f8',
#  -0.060753158564276: 'bad0f8',
#  -0.060621711613003976: 'bad0f8',
#  -0.060611393869707965: 'bad0f8',
#  -0.06047424875828096: 'bbd1f8',
#  -0.06033624413643967: 'bbd1f8',
#  -0.06016020639812403: 'bbd1f8',
#  -0.06011439555214174: 'bbd1f8',
#  -0.059921752340518525: 'bbd1f8',
#  -0.05989743953811647: 'bbd1f8',
#  -0.05983750500692909: 'bbd1f8',
#  -0.05972825238642922: 'bbd1f8',
#  -0.059663797443681235: 'bbd1f8',
#  -0.05953461540684651: 'bbd1f8',
#  -0.05952111467075503: 'bbd1f8',
#  -0.0592768053423196: 'bbd1f8',
#  -0.059071281934583865: 'bbd1f8',
#  -0.05872267983680722: 'bbd1f8',
#  -0.058695291101601606: 'bbd1f8',
#  -0.05835284438282051: 'bcd2f7',
#  -0.058331113497630836: 'bcd2f7',
#  -0.058324214966200626: 'bcd2f7',
#  -0.05811289694948691: 'bcd2f7',
#  -0.05807352866172768: 'bcd2f7',
#  -0.05803621521523707: 'bcd2f7',
#  -0.05787773610191792: 'bcd2f7',
#  -0.05784565816849901: 'bcd2f7',
#  -0.05760309770032955: 'bcd2f7',
#  -0.057560821850392685: 'bcd2f7',
#  -0.05752079075732281: 'bcd2f7',
#  -0.05751893215585731: 'bcd2f7',
#  -0.05706223967147444: 'bcd2f7',
#  -0.05704594194047185: 'bcd2f7',
#  -0.05686089903602672: 'bcd2f7',
#  -0.05652883917966484: 'bcd2f7',
#  -0.05641654541706331: 'bed2f6',
#  -0.056197425747568176: 'bed2f6',
#  -0.05616241246431723: 'bed2f6',
#  -0.05563290955793411: 'bed2f6',
#  -0.05560224647616197: 'bed2f6',
#  -0.055530209539239046: 'bed2f6',
#  -0.055518336692928355: 'bed2f6',
#  -0.055388204375905456: 'bed2f6',
#  -0.05533524331522033: 'bed2f6',
#  -0.055251812838024876: 'bed2f6',
#  -0.055106746943437236: 'bed2f6',
#  -0.05509028395267714: 'bed2f6',
#  -0.0550660553041466: 'bed2f6',
#  -0.05497646552404939: 'bed2f6',
#  -0.05478950652853373: 'bed2f6',
#  -0.0547793265346245: 'bed2f6',
#  -0.05471156898692834: 'bed2f6',
#  -0.05469928498018607: 'bed2f6',
#  -0.05439410830491762: 'bfd3f6',
#  -0.05438489563818057: 'bfd3f6',
#  -0.054289972491482784: 'bfd3f6',
#  -0.0542575687733031: 'bfd3f6',
#  -0.054187779978309376: 'bfd3f6',
#  -0.05407427579207894: 'bfd3f6',
#  -0.053868314911985064: 'bfd3f6',
#  -0.05368368346356878: 'bfd3f6',
#  -0.05354733326423089: 'bfd3f6',
#  -0.053487550551576495: 'bfd3f6',
#  -0.053452272340866906: 'bfd3f6',
#  -0.053434521945895035: 'bfd3f6',
#  -0.05338677215625394: 'bfd3f6',
#  -0.05325600181210774: 'bfd3f6',
#  -0.05303669068794159: 'bfd3f6',
#  -0.05293796443128386: 'bfd3f6',
#  -0.05279330429523847: 'bfd3f6',
#  -0.0527403227834405: 'bfd3f6',
#  -0.05273445240746123: 'bfd3f6',
#  -0.052589076844059765: 'bfd3f6',
#  -0.052509469901884154: 'bfd3f6',
#  -0.05236754125560931: 'c0d4f5',
#  -0.052346248022950244: 'c0d4f5',
#  -0.05204419889689786: 'c0d4f5',
#  -0.05195523785439226: 'c0d4f5',
#  -0.051853833261072645: 'c0d4f5',
#  -0.05179294924305341: 'c0d4f5',
#  -0.051785607696004037: 'c0d4f5',
#  -0.05167693224732927: 'c0d4f5',
#  -0.05136756882484082: 'c0d4f5',
#  -0.051354842859843264: 'c0d4f5',
#  -0.05120462544851877: 'c0d4f5',
#  -0.051033107177777176: 'c0d4f5',
#  -0.05099105001870589: 'c0d4f5',
#  -0.05098850040773497: 'c0d4f5',
#  -0.05095107797764721: 'c0d4f5',
#  -0.05090037627027332: 'c0d4f5',
#  -0.05080339735623506: 'c0d4f5',
#  -0.05079807811391932: 'c0d4f5',
#  -0.05074682555889513: 'c0d4f5',
#  -0.050667770962177325: 'c0d4f5',
#  -0.050528553130357395: 'c0d4f5',
#  -0.05049836699463413: 'c0d4f5',
#  -0.05043068808783807: 'c1d4f4',
#  -0.05041027417877961: 'c1d4f4',
#  -0.05031928224695047: 'c1d4f4',
#  -0.0501519128744709: 'c1d4f4',
#  -0.05009990458825622: 'c1d4f4',
#  -0.05005763736942629: 'c1d4f4',
#  -0.049889316745752615: 'c1d4f4',
#  -0.04985028922340109: 'c1d4f4',
#  -0.04976209721838583: 'c1d4f4',
#  -0.049727611641460286: 'c1d4f4',
#  -0.04959515457229841: 'c1d4f4',
#  -0.049430757583545: 'c1d4f4',
#  -0.04932027259139476: 'c1d4f4',
#  -0.04917112594530793: 'c1d4f4',
#  -0.049076607569674656: 'c1d4f4',
#  -0.04906016877457041: 'c1d4f4',
#  -0.04905381659762918: 'c1d4f4',
#  -0.049044111693275175: 'c1d4f4',
#  -0.04899894951262711: 'c1d4f4',
#  -0.048945984417537065: 'c1d4f4',
#  -0.04891915778024981: 'c1d4f4',
#  -0.0488734419560581: 'c1d4f4',
#  -0.04872790266856715: 'c1d4f4',
#  -0.04872660922132218: 'c1d4f4',
#  -0.04858839292528972: 'c1d4f4',
#  -0.048511411291824166: 'c1d4f4',
#  -0.04842962673923641: 'c3d5f4',
#  -0.04842564700877855: 'c3d5f4',
#  -0.0483515618206849: 'c3d5f4',
#  -0.048247239304828056: 'c3d5f4',
#  -0.04821655819823531: 'c3d5f4',
#  -0.04814577409729718: 'c3d5f4',
#  -0.04813219711142375: 'c3d5f4',
#  -0.048110326292658746: 'c3d5f4',
#  -0.048068673423575195: 'c3d5f4',
#  -0.04794740397819734: 'c3d5f4',
#  -0.047883131826183416: 'c3d5f4',
#  -0.04778985112109715: 'c3d5f4',
#  -0.04776763375702907: 'c3d5f4',
#  -0.047714598998265606: 'c3d5f4',
#  -0.047665874939792116: 'c3d5f4',
#  -0.04762227334505167: 'c3d5f4',
#  -0.04745436368177934: 'c3d5f4',
#  -0.04736123619790727: 'c3d5f4',
#  -0.047161172180255936: 'c3d5f4',
#  -0.046877257525282594: 'c3d5f4',
#  -0.046863232800468835: 'c3d5f4',
#  -0.046719096996815514: 'c3d5f4',
#  -0.046702913841608504: 'c3d5f4',
#  -0.04668373361899438: 'c3d5f4',
#  -0.04650015219045121: 'c3d5f4',
#  -0.046497669197809344: 'c3d5f4',
#  -0.046393639038290094: 'c4d5f3',
#  -0.0463605699588956: 'c4d5f3',
#  -0.04632278173476269: 'c4d5f3',
#  -0.04601406589010822: 'c4d5f3',
#  -0.045940710250762455: 'c4d5f3',
#  -0.04572441616445435: 'c4d5f3',
#  -0.04568645554519908: 'c4d5f3',
#  -0.045662877633608545: 'c4d5f3',
#  -0.0456291132547279: 'c4d5f3',
#  -0.04560807266873682: 'c4d5f3',
#  -0.04548420920019675: 'c4d5f3',
#  -0.04545940687012707: 'c4d5f3',
#  -0.045454343758473154: 'c4d5f3',
#  -0.045038806100749: 'c4d5f3',
#  -0.04496537008130335: 'c4d5f3',
#  -0.04464245374833564: 'c4d5f3',
#  -0.044489240224694686: 'c4d5f3',
#  -0.044468085184102175: 'c4d5f3',
#  -0.04446642789274293: 'c4d5f3',
#  -0.04434076461171151: 'c5d6f2',
#  -0.0442306482765917: 'c5d6f2',
#  -0.044179971856015215: 'c5d6f2',
#  -0.044060068517075855: 'c5d6f2',
#  -0.043986155258229215: 'c5d6f2',
#  -0.04396543527176211: 'c5d6f2',
#  -0.04396365994285551: 'c5d6f2',
#  -0.04393953819150701: 'c5d6f2',
#  -0.043823730180677097: 'c5d6f2',
#  -0.043768190644722524: 'c5d6f2',
#  -0.04364950547341715: 'c5d6f2',
#  -0.043649112681817266: 'c5d6f2',
#  -0.04364286966157443: 'c5d6f2',
#  -0.0435210236292488: 'c5d6f2',
#  -0.04346422861084046: 'c5d6f2',
#  -0.04342017351470763: 'c5d6f2',
#  -0.043382568194435686: 'c5d6f2',
#  -0.04338228905908819: 'c5d6f2',
#  -0.043289283852448776: 'c5d6f2',
#  -0.043157476430306235: 'c5d6f2',
#  -0.04304114060607801: 'c5d6f2',
#  -0.042999343789066446: 'c5d6f2',
#  -0.04289159065168927: 'c5d6f2',
#  -0.04279547996225765: 'c5d6f2',
#  -0.042791671363826916: 'c5d6f2',
#  -0.042781362780065: 'c5d6f2',
#  -0.04250771939036887: 'c5d6f2',
#  -0.04246287569291536: 'c5d6f2',
#  -0.04243538307308754: 'c5d6f2',
#  -0.04235392361476971: 'c6d6f1',
#  -0.04235023526950946: 'c6d6f1',
#  -0.04228573550161445: 'c6d6f1',
#  -0.04225114911365892: 'c6d6f1',
#  -0.04212656740627663: 'c6d6f1',
#  -0.042116329895591643: 'c6d6f1',
#  -0.04203044209493579: 'c6d6f1',
#  -0.041982382402420665: 'c6d6f1',
#  -0.04180062587166505: 'c6d6f1',
#  -0.04170763057726765: 'c6d6f1',
#  -0.041664157667782295: 'c6d6f1',
#  -0.041624872505097325: 'c6d6f1',
#  -0.041563278921701: 'c6d6f1',
#  -0.04144766515536436: 'c6d6f1',
#  -0.04137419486266564: 'c6d6f1',
#  -0.04136265499288391: 'c6d6f1',
#  -0.041334332299293196: 'c6d6f1',
#  -0.04130608243456122: 'c6d6f1',
#  -0.041219539782853: 'c6d6f1',
#  -0.04114880261395783: 'c6d6f1',
#  -0.0410993016378397: 'c6d6f1',
#  -0.041092110123013566: 'c6d6f1',
#  -0.04109148045039514: 'c6d6f1',
#  -0.040773184048555636: 'c6d6f1',
#  -0.040724944412336324: 'c6d6f1',
#  -0.04061949148358827: 'c6d6f1',
#  -0.04058035949287904: 'c6d6f1',
#  -0.04050745477323237: 'c6d6f1',
#  -0.040396047975166265: 'c6d6f1',
#  -0.040349770390662926: 'c7d7f0',
#  -0.040337318632929726: 'c7d7f0',
#  -0.04029453152235394: 'c7d7f0',
#  -0.04024134669273681: 'c7d7f0',
#  -0.04013720452113667: 'c7d7f0',
#  -0.04005241507755739: 'c7d7f0',
#  -0.0400323224171485: 'c7d7f0',
#  -0.04002120591750766: 'c7d7f0',
#  -0.039982501542085463: 'c7d7f0',
#  -0.039981724083080254: 'c7d7f0',
#  -0.03977105501762331: 'c7d7f0',
#  -0.03974754542174725: 'c7d7f0',
#  -0.03974667744906494: 'c7d7f0',
#  -0.0396739205919582: 'c7d7f0',
#  -0.03957691993036391: 'c7d7f0',
#  -0.03951258037219566: 'c7d7f0',
#  -0.039505225963053434: 'c7d7f0',
#  -0.039365252346084935: 'c7d7f0',
#  -0.03934935497283673: 'c7d7f0',
#  -0.03934228056831575: 'c7d7f0',
#  -0.03919427517193897: 'c7d7f0',
#  -0.03904014087298923: 'c7d7f0',
#  -0.038826193936020874: 'c7d7f0',
#  -0.038825796708317574: 'c7d7f0',
#  -0.03881961715135592: 'c7d7f0',
#  -0.038783877661152634: 'c7d7f0',
#  -0.038781281452767706: 'c7d7f0',
#  -0.03877697327172143: 'c7d7f0',
#  -0.0386859996369601: 'c7d7f0',
#  -0.038623787071543556: 'c7d7f0',
#  -0.03857895546324888: 'c7d7f0',
#  -0.0385317020263052: 'c7d7f0',
#  -0.0384822316414641: 'c7d7f0',
#  -0.038474894163355505: 'c7d7f0',
#  -0.038445133891479834: 'c7d7f0',
#  -0.03822024267570783: 'c9d7f0',
#  -0.038200016644616044: 'c9d7f0',
#  -0.03816732771787874: 'c9d7f0',
#  -0.03816078012611903: 'c9d7f0',
#  -0.03813809866914091: 'c9d7f0',
#  -0.03807764487232625: 'c9d7f0',
#  -0.03800119626881802: 'c9d7f0',
#  -0.037985395837602215: 'c9d7f0',
#  -0.037898701580660145: 'c9d7f0',
#  -0.03781690801655412: 'c9d7f0',
#  -0.03776957792618285: 'c9d7f0',
#  -0.03768234219927589: 'c9d7f0',
#  -0.03764755940755209: 'c9d7f0',
#  -0.03761017733433733: 'c9d7f0',
#  -0.03760622082755373: 'c9d7f0',
#  -0.03757813507114: 'c9d7f0',
#  -0.03753801159659363: 'c9d7f0',
#  -0.03750316960494218: 'c9d7f0',
#  -0.037502161168466434: 'c9d7f0',
#  -0.03749059727213929: 'c9d7f0',
#  -0.037453259382595375: 'c9d7f0',
#  -0.03739422316001929: 'c9d7f0',
#  -0.03738597823702185: 'c9d7f0',
#  -0.0373508375908862: 'c9d7f0',
#  -0.03717272600752283: 'c9d7f0',
#  -0.03716222554504166: 'c9d7f0',
#  -0.0371174151551508: 'c9d7f0',
#  -0.03708193486229298: 'c9d7f0',
#  -0.03708114987759363: 'c9d7f0',
#  -0.03707942935438979: 'c9d7f0',
#  -0.03692778076461168: 'c9d7f0',
#  -0.03683624096656275: 'c9d7f0',
#  -0.036787678900413553: 'c9d7f0',
#  -0.0367473166119502: 'c9d7f0',
#  -0.036731116278938096: 'c9d7f0',
#  -0.03661066784169866: 'c9d7f0',
#  -0.03659291095357896: 'c9d7f0',
#  -0.03650499063105897: 'c9d7f0',
#  -0.03650072501688494: 'c9d7f0',
#  -0.03648079028931021: 'c9d7f0',
#  -0.03643469436274464: 'c9d7f0',
#  -0.036418577111743705: 'c9d7f0',
#  -0.03640012811833758: 'c9d7f0',
#  -0.03637831643196326: 'c9d7f0',
#  0: 'dddcdc',
#  0.03630790072242321: 'edd2c3',
#  0.03637354722151457: 'edd1c2',
#  0.03640760448666633: 'edd1c2',
#  0.03642175539953831: 'edd1c2',
#  0.036516136049094476: 'edd1c2',
#  0.0365221427903865: 'edd1c2',
#  0.036563539383358726: 'edd1c2',
#  0.03656531674361313: 'edd1c2',
#  0.036571533930251435: 'edd1c2',
#  0.036586810409350044: 'edd1c2',
#  0.03658935567538907: 'edd1c2',
#  0.03659842761521828: 'edd1c2',
#  0.036611082350004605: 'edd1c2',
#  0.03666387204268065: 'edd1c2',
#  0.03676062402471922: 'edd1c2',
#  0.036768963622333874: 'edd1c2',
#  0.036786573758681475: 'edd1c2',
#  0.03679119034791053: 'edd1c2',
#  0.03686743796108341: 'edd1c2',
#  0.03688585118163451: 'edd1c2',
#  0.036910250686448064: 'edd1c2',
#  0.03691493281234486: 'edd1c2',
#  0.03692090203534539: 'edd1c2',
#  0.036936358904717234: 'edd1c2',
#  0.036949286436977376: 'edd1c2',
#  0.03698384379855469: 'edd1c2',
#  0.036991543452405386: 'edd1c2',
#  0.03705385639607198: 'edd1c2',
#  0.0371614643863806: 'edd1c2',
#  0.03723247081174581: 'edd1c2',
#  0.03726019259667738: 'edd1c2',
#  0.0373779467345579: 'edd1c2',
#  0.037390728483886415: 'edd1c2',
#  0.03746968316719843: 'edd1c2',
#  0.037528274658809: 'edd1c2',
#  0.03757309373618766: 'edd1c2',
#  0.03761461086108167: 'edd1c2',
#  0.037728307992602905: 'edd1c2',
#  0.03780185951123468: 'edd1c2',
#  0.03787868571899661: 'edd1c2',
#  0.03788297839088214: 'edd1c2',
#  0.03795503209641765: 'edd1c2',
#  0.0379676722752364: 'edd1c2',
#  0.038016865030224126: 'edd1c2',
#  0.038081205396441505: 'edd1c2',
#  0.03816639826678446: 'edd1c2',
#  0.038180163419169556: 'edd1c2',
#  0.03819636601790414: 'edd1c2',
#  0.038262554297704844: 'edd1c2',
#  0.03826362411812327: 'edd1c2',
#  0.038270938374332396: 'edd1c2',
#  0.03827986932484262: 'edd1c2',
#  0.0382943282637989: 'edd1c2',
#  0.03830283434047524: 'edd1c2',
#  0.03838575604328888: 'eed0c0',
#  0.03841127047061797: 'eed0c0',
#  0.03841833465313361: 'eed0c0',
#  0.038424009317099946: 'eed0c0',
#  0.03843005455679473: 'eed0c0',
#  0.03846128948126464: 'eed0c0',
#  0.03863241014344058: 'eed0c0',
#  0.03863978019011792: 'eed0c0',
#  0.038727176708749866: 'eed0c0',
#  0.03873360424227166: 'eed0c0',
#  0.03875525731302636: 'eed0c0',
#  0.038815210737358725: 'eed0c0',
#  0.038884739803720786: 'eed0c0',
#  0.03898038622389608: 'eed0c0',
#  0.039021134904414244: 'eed0c0',
#  0.039061374818972865: 'eed0c0',
#  0.03912168192764505: 'eed0c0',
#  0.03914845789531493: 'eed0c0',
#  0.03916591080143246: 'eed0c0',
#  0.03919008342594371: 'eed0c0',
#  0.039237076065458995: 'eed0c0',
#  0.03924859036644377: 'eed0c0',
#  0.039314596758167834: 'eed0c0',
#  0.03934551316011373: 'eed0c0',
#  0.03934654708323906: 'eed0c0',
#  0.03938578691459156: 'eed0c0',
#  0.039474440666932946: 'eed0c0',
#  0.03955988411483346: 'eed0c0',
#  0.03962908145365814: 'eed0c0',
#  0.039648800374160284: 'eed0c0',
#  0.03965687863994703: 'eed0c0',
#  0.039715315599724486: 'eed0c0',
#  0.03984191169705958: 'eed0c0',
#  0.03997433138125018: 'eed0c0',
#  0.04005346376133235: 'eed0c0',
#  0.04011422181221215: 'eed0c0',
#  0.04026920003644209: 'eed0c0',
#  0.04028044105364685: 'eed0c0',
#  0.04041394630939777: 'efcfbf',
#  0.04046968736389121: 'efcfbf',
#  0.040470210258292026: 'efcfbf',
#  0.04051970879447298: 'efcfbf',
#  0.04052079962767552: 'efcfbf',
#  0.0405616546002489: 'efcfbf',
#  0.04064990428036868: 'efcfbf',
#  0.04068354374444943: 'efcfbf',
#  0.04072957332802823: 'efcfbf',
#  0.040916951461545885: 'efcfbf',
#  0.04095068661729313: 'efcfbf',
#  0.04095955497269338: 'efcfbf',
#  0.040988343910653896: 'efcfbf',
#  0.04101033912890652: 'efcfbf',
#  0.04105876926972423: 'efcfbf',
#  0.04106485367691988: 'efcfbf',
#  0.0410790000093936: 'efcfbf',
#  0.04109040950412568: 'efcfbf',
#  0.04118125710966473: 'efcfbf',
#  0.04118486067282545: 'efcfbf',
#  0.04118816777662407: 'efcfbf',
#  0.0412538033119525: 'efcfbf',
#  0.04128118124848747: 'efcfbf',
#  0.04131071154414179: 'efcfbf',
#  0.04131766367171745: 'efcfbf',
#  0.0413294023355694: 'efcfbf',
#  0.041461022310778646: 'efcfbf',
#  0.04150845320074824: 'efcfbf',
#  0.04158794551714962: 'efcfbf',
#  0.04160743432347619: 'efcfbf',
#  0.041684810285256606: 'efcfbf',
#  0.04186040067427647: 'efcfbf',
#  0.04186395498238642: 'efcfbf',
#  0.041892274125317416: 'efcfbf',
#  0.04192261947957377: 'efcfbf',
#  0.041924281102052235: 'efcfbf',
#  0.04195504272907741: 'efcfbf',
#  0.04195871857228298: 'efcfbf',
#  0.042035823797003075: 'efcfbf',
#  0.04205688485021289: 'efcfbf',
#  0.04206265991648668: 'efcfbf',
#  0.04207727447005102: 'efcfbf',
#  0.042149746261157625: 'efcfbf',
#  0.04218009746264007: 'efcfbf',
#  0.04225496631408262: 'efcfbf',
#  0.042258568421319385: 'efcfbf',
#  0.04227502615717268: 'efcfbf',
#  0.04236434135918973: 'efcfbf',
#  0.04242253633235192: 'efcebd',
#  0.042434887422530126: 'efcebd',
#  0.042439415669055486: 'efcebd',
#  0.04245615161491723: 'efcebd',
#  0.04246090768742731: 'efcebd',
#  0.0424729753166242: 'efcebd',
#  0.042478512241467155: 'efcebd',
#  0.042498605129470374: 'efcebd',
#  0.04262503490560649: 'efcebd',
#  0.042695186804709545: 'efcebd',
#  0.04269747918351727: 'efcebd',
#  0.04270197373101455: 'efcebd',
#  0.0427603912627265: 'efcebd',
#  0.042767798542488564: 'efcebd',
#  0.0428636076464317: 'efcebd',
#  0.042935671453946764: 'efcebd',
#  0.04298884108036253: 'efcebd',
#  0.04313039191492539: 'efcebd',
#  0.04313897238144561: 'efcebd',
#  0.04315921748373181: 'efcebd',
#  0.043192877194235105: 'efcebd',
#  0.04335307087241719: 'efcebd',
#  0.04337679924593143: 'efcebd',
#  0.043413060341820665: 'efcebd',
#  0.04343440818365987: 'efcebd',
#  0.04359967887146328: 'efcebd',
#  0.04375210730880869: 'efcebd',
#  0.04377229925598559: 'efcebd',
#  0.043803925938969486: 'efcebd',
#  0.043810665980915695: 'efcebd',
#  0.043831916107809094: 'efcebd',
#  0.043861463681118026: 'efcebd',
#  0.043993423006509096: 'efcebd',
#  0.04401408315005304: 'efcebd',
#  0.04401464992443505: 'efcebd',
#  0.044073257125237644: 'efcebd',
#  0.04408494663180021: 'efcebd',
#  0.04449219892454135: 'f0cdbb',
#  0.04450424627368572: 'f0cdbb',
#  0.04454591282485011: 'f0cdbb',
#  0.044689730298151494: 'f0cdbb',
#  0.04474670862070688: 'f0cdbb',
#  0.04478414310751759: 'f0cdbb',
#  0.04486544180200716: 'f0cdbb',
#  0.044976880548512656: 'f0cdbb',
#  0.044992521552824044: 'f0cdbb',
#  0.04505002640944076: 'f0cdbb',
#  0.045200825015146086: 'f0cdbb',
#  0.04520474357928199: 'f0cdbb',
#  0.04524023244081768: 'f0cdbb',
#  0.04527758733905207: 'f0cdbb',
#  0.045340305241587685: 'f0cdbb',
#  0.045363378096861674: 'f0cdbb',
#  0.04544077385351059: 'f0cdbb',
#  0.04551805732259639: 'f0cdbb',
#  0.04555842968904686: 'f0cdbb',
#  0.04568462663323635: 'f0cdbb',
#  0.04572788444108712: 'f0cdbb',
#  0.04574886964434783: 'f0cdbb',
#  0.04575158845398096: 'f0cdbb',
#  0.04576096520379404: 'f0cdbb',
#  0.04576447488617128: 'f0cdbb',
#  0.045792747129212275: 'f0cdbb',
#  0.045796431678426446: 'f0cdbb',
#  0.04581809287597407: 'f0cdbb',
#  0.04587544311641847: 'f0cdbb',
#  0.046012089837290916: 'f0cdbb',
#  0.04603523543880581: 'f0cdbb',
#  0.046079261850273494: 'f0cdbb',
#  0.046108275163317475: 'f0cdbb',
#  0.046121735781764955: 'f0cdbb',
#  0.04613319913091109: 'f0cdbb',
#  0.04627830149023019: 'f0cdbb',
#  0.04631010663744323: 'f0cdbb',
#  0.04633011380850246: 'f0cdbb',
#  0.046339802928066824: 'f0cdbb',
#  0.046372029576216604: 'f0cdbb',
#  0.046500133516038974: 'f1cdba',
#  0.04656224560530123: 'f1cdba',
#  0.04661322506178521: 'f1cdba',
#  0.046705364726845826: 'f1cdba',
#  0.04672136756260442: 'f1cdba',
#  0.04675465792880552: 'f1cdba',
#  0.04685751066484557: 'f1cdba',
#  0.046877297323238136: 'f1cdba',
#  0.046941072812232504: 'f1cdba',
#  0.04697588202844031: 'f1cdba',
#  0.0470226174692111: 'f1cdba',
#  0.04708077716826469: 'f1cdba',
#  0.047148930786730596: 'f1cdba',
#  0.04719301088623249: 'f1cdba',
#  0.04726802498522992: 'f1cdba',
#  0.04729675399558522: 'f1cdba',
#  0.047301920148453504: 'f1cdba',
#  0.04733504638210094: 'f1cdba',
#  0.047360952537235435: 'f1cdba',
#  0.047488856810045714: 'f1cdba',
#  0.04753559596369658: 'f1cdba',
#  0.04756407367519346: 'f1cdba',
#  0.04759824008495689: 'f1cdba',
#  0.04770170290247148: 'f1cdba',
#  0.04777211629652462: 'f1cdba',
#  0.04778433349129224: 'f1cdba',
#  0.047833039181919154: 'f1cdba',
#  0.04788241279350564: 'f1cdba',
#  0.04788406079329704: 'f1cdba',
#  0.047910380054928446: 'f1cdba',
#  0.04827211378507487: 'f1cdba',
#  0.04832053878434571: 'f1cdba',
#  0.04852967289274731: 'f1ccb8',
#  0.04857414566204919: 'f1ccb8',
#  0.048631982010870344: 'f1ccb8',
#  0.04864124583629708: 'f1ccb8',
#  0.048649868968210344: 'f1ccb8',
#  0.04872338555937245: 'f1ccb8',
#  0.04874112906078073: 'f1ccb8',
#  0.04878653562281492: 'f1ccb8',
#  0.0488417715159922: 'f1ccb8',
#  0.048874059355612745: 'f1ccb8',
#  0.04888054955701147: 'f1ccb8',
#  0.04891868089668577: 'f1ccb8',
#  0.048925821151813084: 'f1ccb8',
#  0.048956428533819214: 'f1ccb8',
#  0.04897057543602685: 'f1ccb8',
#  0.04911959181089074: 'f1ccb8',
#  0.049124377252483496: 'f1ccb8',
#  0.04919692853541061: 'f1ccb8',
#  0.04925376271893309: 'f1ccb8',
#  0.0492821989852523: 'f1ccb8',
#  0.04936801235566647: 'f1ccb8',
#  0.049382905455746605: 'f1ccb8',
#  0.04938798457449815: 'f1ccb8',
#  0.04943687427864435: 'f1ccb8',
#  0.049486671485295314: 'f1ccb8',
#  0.049509587742910664: 'f1ccb8',
#  0.049635257507582464: 'f1ccb8',
#  0.04966375441615449: 'f1ccb8',
#  0.04967322649632448: 'f1ccb8',
#  0.04975523063754786: 'f1ccb8',
#  0.04978439796058124: 'f1ccb8',
#  0.04979376414472186: 'f1ccb8',
#  0.0498158933061405: 'f1ccb8',
#  0.04982518681866321: 'f1ccb8',
#  0.04985844528789085: 'f1ccb8',
#  0.04991805075728357: 'f1ccb8',
#  0.04993033746839874: 'f1ccb8',
#  0.0499913167513248: 'f1ccb8',
#  0.0499934294541732: 'f1ccb8',
#  0.050090349207363154: 'f1ccb8',
#  0.050164922822285636: 'f1ccb8',
#  0.05020417131545144: 'f1ccb8',
#  0.05025771456188278: 'f1ccb8',
#  0.05026010267866131: 'f1ccb8',
#  0.050337096359212866: 'f1ccb8',
#  0.05059507510291647: 'f2cbb7',
#  0.05077065378230709: 'f2cbb7',
#  0.05078683464152476: 'f2cbb7',
#  0.050793380746449186: 'f2cbb7',
#  0.050798726763916946: 'f2cbb7',
#  0.0508346079478686: 'f2cbb7',
#  0.050949232225915166: 'f2cbb7',
#  0.05101463320556155: 'f2cbb7',
#  0.051091056476222876: 'f2cbb7',
#  0.05116236700341689: 'f2cbb7',
#  0.051218818750510486: 'f2cbb7',
#  0.051228654584207015: 'f2cbb7',
#  0.051233560225183675: 'f2cbb7',
#  0.05139402796214075: 'f2cbb7',
#  0.05141335336558695: 'f2cbb7',
#  0.051458817566215065: 'f2cbb7',
#  0.05146496639272512: 'f2cbb7',
#  0.05147182853112001: 'f2cbb7',
#  0.05162058393914717: 'f2cbb7',
#  0.051709406714240264: 'f2cbb7',
#  0.05172568395097146: 'f2cbb7',
#  0.051769150000602726: 'f2cbb7',
#  0.05180607268056672: 'f2cbb7',
#  0.0518145028518103: 'f2cbb7',
#  0.05187161506209729: 'f2cbb7',
#  0.05192462834491032: 'f2cbb7',
#  0.05194024783475077: 'f2cbb7',
#  0.05202512852832771: 'f2cbb7',
#  0.05204236361273947: 'f2cbb7',
#  0.052052018017943937: 'f2cbb7',
#  0.052067462123319176: 'f2cbb7',
#  0.05208596321223847: 'f2cbb7',
#  0.05216971873121584: 'f2cbb7',
#  0.052256734644227434: 'f2cbb7',
#  0.05226471095212739: 'f2cbb7',
#  0.05227552858600959: 'f2cbb7',
#  0.05231297028148353: 'f2cbb7',
#  0.05232716987513298: 'f2cbb7',
#  0.052613450764770774: 'f2cab5',
#  0.05262362150713214: 'f2cab5',
#  0.05264243370954518: 'f2cab5',
#  0.05268728412389252: 'f2cab5',
#  0.052715690017715505: 'f2cab5',
#  0.052783162567350154: 'f2cab5',
#  0.05280009880144272: 'f2cab5',
#  0.05296483884293995: 'f2cab5',
#  0.05302303511224096: 'f2cab5',
#  0.053123285461273685: 'f2cab5',
#  0.053180784963640496: 'f2cab5',
#  0.053201655985120555: 'f2cab5',
#  0.05320446452136869: 'f2cab5',
#  0.05321240269429737: 'f2cab5',
#  0.05321390140980444: 'f2cab5',
#  0.05329305008977934: 'f2cab5',
#  0.05330607005241918: 'f2cab5',
#  0.053308034114561996: 'f2cab5',
#  0.053389534236908474: 'f2cab5',
#  0.053407575320557864: 'f2cab5',
#  0.053438937311678376: 'f2cab5',
#  0.05349307601657872: 'f2cab5',
#  0.05351526589070552: 'f2cab5',
#  0.05356291366085329: 'f2cab5',
#  0.0536268496287462: 'f2cab5',
#  0.05366498614790823: 'f2cab5',
#  0.05366906307817162: 'f2cab5',
#  0.053879280044052034: 'f2cab5',
#  0.05390527658779886: 'f2cab5',
#  0.05393232828599801: 'f2cab5',
#  0.05393452296481259: 'f2cab5',
#  0.053960746687069495: 'f2cab5',
#  0.05396349967792778: 'f2cab5',
#  0.05400738170449746: 'f2cab5',
#  0.0541874311105154: 'f2cab5',
#  0.054193377670305146: 'f2cab5',
#  0.054269604344990646: 'f2cab5',
#  0.05427178065811917: 'f2cab5',
#  0.05427447245563308: 'f2cab5',
#  0.05435840364439466: 'f2cab5',
#  0.054360134617159765: 'f2cab5',
#  0.05439386812257767: 'f2cab5',
#  0.05453688349623293: 'f2c9b4',
#  0.05470968868159545: 'f2c9b4',
#  0.05480331653865643: 'f2c9b4',
#  0.054895361617439256: 'f2c9b4',
#  0.055008672353471795: 'f2c9b4',
#  0.055064269044589095: 'f2c9b4',
#  0.05510025442919846: 'f2c9b4',
#  0.05518269186282418: 'f2c9b4',
#  0.05520957682086055: 'f2c9b4',
#  0.05522523671192968: 'f2c9b4',
#  0.05531111555261394: 'f2c9b4',
#  0.05532167075789138: 'f2c9b4',
#  0.055451592632829415: 'f2c9b4',
#  0.05547727123751873: 'f2c9b4',
#  0.055489711618933325: 'f2c9b4',
#  0.055496425935577284: 'f2c9b4',
#  0.05568754656081835: 'f2c9b4',
#  0.05574315580028229: 'f2c9b4',
#  0.055774467227945414: 'f2c9b4',
#  0.05581496192883463: 'f2c9b4',
#  0.05582396374689723: 'f2c9b4',
#  0.05587188740224043: 'f2c9b4',
#  0.0559371492721576: 'f2c9b4',
#  0.05598311621989352: 'f2c9b4',
#  0.05612441064366456: 'f2c9b4',
#  0.05618519173897589: 'f2c9b4',
#  0.05620791682978525: 'f2c9b4',
#  0.056254388346970996: 'f2c9b4',
#  0.05630547259356429: 'f2c9b4',
#  0.05647697723735867: 'f2c9b4',
#  0.05650671809063732: 'f2c9b4',
#  0.056517779847658746: 'f2c9b4',
#  0.05654569841111228: 'f3c8b2',
#  0.05666365420111008: 'f3c8b2',
#  0.056726179578018295: 'f3c8b2',
#  0.056860257086337226: 'f3c8b2',
#  0.05691843483924955: 'f3c8b2',
#  0.05704276688566581: 'f3c8b2',
#  0.05707132431315324: 'f3c8b2',
#  0.05714543927614682: 'f3c8b2',
#  0.05722864162497668: 'f3c8b2',
#  0.05734061822258084: 'f3c8b2',
#  0.057421105502355206: 'f3c8b2',
#  0.057436601031909916: 'f3c8b2',
#  0.05748920366899128: 'f3c8b2',
#  0.05749826688100859: 'f3c8b2',
#  0.05766639686098462: 'f3c8b2',
#  0.057693323571496584: 'f3c8b2',
#  0.05769770534055072: 'f3c8b2',
#  0.05773511571173473: 'f3c8b2',
#  0.057845498500556015: 'f3c8b2',
#  0.057860002179374634: 'f3c8b2',
#  0.05792443757507111: 'f3c8b2',
#  0.05794748058109629: 'f3c8b2',
#  0.058027745442817344: 'f3c8b2',
#  0.05808045541820819: 'f3c8b2',
#  0.0582062676988995: 'f3c8b2',
#  0.058225738015507: 'f3c8b2',
#  0.058302379237419696: 'f3c8b2',
#  0.058375737715691205: 'f3c8b2',
#  0.05838981778655693: 'f3c8b2',
#  0.05840743594903481: 'f3c8b2',
#  0.05846292046195748: 'f3c8b2',
#  0.05852525048973519: 'f3c8b2',
#  0.05854110662907391: 'f3c8b2',
#  0.05859549427355808: 'f3c7b1',
#  0.058620455123408: 'f3c7b1',
#  0.05862953514569403: 'f3c7b1',
#  0.05865442993213419: 'f3c7b1',
#  0.058670196127278966: 'f3c7b1',
#  0.05880402065205509: 'f3c7b1',
#  0.058935203413963744: 'f3c7b1',
#  0.05895242325726324: 'f3c7b1',
#  0.05895473653723845: 'f3c7b1',
#  0.05913477590821432: 'f3c7b1',
#  0.059205745743612787: 'f3c7b1',
#  0.05921530801857487: 'f3c7b1',
#  0.059344065130439196: 'f3c7b1',
#  0.05936466083035518: 'f3c7b1',
#  0.059429012667186996: 'f3c7b1',
#  0.059429267254216864: 'f3c7b1',
#  0.05946956911042866: 'f3c7b1',
#  0.059525345714258875: 'f3c7b1',
#  0.05955601531145779: 'f3c7b1',
#  0.05956711477747755: 'f3c7b1',
#  0.059574641337169464: 'f3c7b1',
#  0.05965117577988252: 'f3c7b1',
#  0.059664146821251776: 'f3c7b1',
#  0.059669433603468935: 'f3c7b1',
#  0.05979464901672245: 'f3c7b1',
#  0.05984882337547326: 'f3c7b1',
#  0.059893081414212825: 'f3c7b1',
#  0.059973116443658915: 'f3c7b1',
#  0.059977288348329744: 'f3c7b1',
#  0.05999598434362615: 'f3c7b1',
#  0.060010706031593336: 'f3c7b1',
#  0.060107014656302415: 'f3c7b1',
#  0.060309018576512594: 'f3c7b1',
#  0.06033941679833309: 'f3c7b1',
#  0.060341604499634084: 'f3c7b1',
#  0.060345576761192: 'f3c7b1',
#  0.060390172676291556: 'f3c7b1',
#  0.06040135919571726: 'f3c7b1',
#  0.060436063633859394: 'f3c7b1',
#  0.060481221127083096: 'f3c7b1',
#  0.06052935100033211: 'f3c7b1',
#  0.06059441221681106: 'f4c6af',
#  0.06060148479443766: 'f4c6af',
#  0.060660359046622: 'f4c6af',
#  0.060714986870870305: 'f4c6af',
#  0.06074885872385436: 'f4c6af',
#  0.0607945547126272: 'f4c6af',
#  0.06081774526235392: 'f4c6af',
#  0.06082161251504933: 'f4c6af',
#  0.060924904021682554: 'f4c6af',
#  0.060952839782771: 'f4c6af',
#  0.06097521386486758: 'f4c6af',
#  0.061074591246237125: 'f4c6af',
#  0.06113456384346532: 'f4c6af',
#  0.061183114315896084: 'f4c6af',
#  0.06127178069947874: 'f4c6af',
#  0.06129028938225666: 'f4c6af',
#  0.061372449679500236: 'f4c6af',
#  0.061378352192679175: 'f4c6af',
#  0.061450466274568315: 'f4c6af',
#  0.06146496504618188: 'f4c6af',
#  0.061480540106904645: 'f4c6af',
#  0.06165247655154506: 'f4c6af',
#  0.06173823075122498: 'f4c6af',
#  0.061833202209446436: 'f4c6af',
#  0.06186043987992093: 'f4c6af',
#  0.06209787792947761: 'f4c6af',
#  0.0622290760788142: 'f4c6af',
#  0.062261643616766255: 'f4c6af',
#  0.062293817234589495: 'f4c6af',
#  0.0625169406885513: 'f4c6af',
#  0.06254133796640542: 'f4c6af',
#  0.06254978962781049: 'f4c6af',
#  0.06262656818408813: 'f4c5ad',
#  0.06268608603858541: 'f4c5ad',
#  0.06268879601117566: 'f4c5ad',
#  0.06268981896096987: 'f4c5ad',
#  0.06277859861652145: 'f4c5ad',
#  0.06283330694328733: 'f4c5ad',
#  0.06286755569018686: 'f4c5ad',
#  0.06289440822291313: 'f4c5ad',
#  0.0629413593113783: 'f4c5ad',
#  0.06298005109450373: 'f4c5ad',
#  0.06303248218462783: 'f4c5ad',
#  0.06308438197554173: 'f4c5ad',
#  0.06314836515898105: 'f4c5ad',
#  0.06321470706506335: 'f4c5ad',
#  0.0632978610620122: 'f4c5ad',
#  0.06332171230830722: 'f4c5ad',
#  0.06332302242082843: 'f4c5ad',
#  0.06336168417499477: 'f4c5ad',
#  0.06340628045862913: 'f4c5ad',
#  0.0635189754576556: 'f4c5ad',
#  0.06356503130262593: 'f4c5ad',
#  0.06362233239677172: 'f4c5ad',
#  0.06366135496855026: 'f4c5ad',
#  0.0637218821278415: 'f4c5ad',
#  0.06376564951169257: 'f4c5ad',
#  0.06383231950131465: 'f4c5ad',
#  0.06388287517609727: 'f4c5ad',
#  0.06389292205972923: 'f4c5ad',
#  0.06399137686518512: 'f4c5ad',
#  0.06406650852496076: 'f4c5ad',
#  0.06427441119552395: 'f4c5ad',
#  0.06429896329876737: 'f4c5ad',
#  0.06440964239559223: 'f4c5ad',
#  0.06449218109141024: 'f4c5ad',
#  0.06451821714920142: 'f4c5ad',
#  0.06452873417021643: 'f4c5ad',
#  0.06457995107149986: 'f4c5ad',
#  0.06469763117494057: 'f5c4ac',
#  0.0647138476387999: 'f5c4ac',
#  0.06477142198206207: 'f5c4ac',
#  0.0647787364678065: 'f5c4ac',
#  0.06487054847715237: 'f5c4ac',
#  0.06487171721890983: 'f5c4ac',
#  0.06490934266664138: 'f5c4ac',
#  0.06492074505126834: 'f5c4ac',
#  0.06497838971155907: 'f5c4ac',
#  0.06505090460228999: 'f5c4ac',
#  0.06508884783391124: 'f5c4ac',
#  0.06515217592289468: 'f5c4ac',
#  0.0651909429818546: 'f5c4ac',
#  0.06520953904192128: 'f5c4ac',
#  0.06523779234776629: 'f5c4ac',
#  0.0653579412921624: 'f5c4ac',
#  0.06543011149261059: 'f5c4ac',
#  0.06548116882147818: 'f5c4ac',
#  0.0655357198985614: 'f5c4ac',
#  0.06556299990114564: 'f5c4ac',
#  0.0656106631332383: 'f5c4ac',
#  0.06570264127894511: 'f5c4ac',
#  0.06571265369529279: 'f5c4ac',
#  0.06571433239899334: 'f5c4ac',
#  0.06579206933234709: 'f5c4ac',
#  0.06582005226188924: 'f5c4ac',
#  0.06583937430340932: 'f5c4ac',
#  0.06594125763048637: 'f5c4ac',
#  0.06595544282121127: 'f5c4ac',
#  0.06597517985499898: 'f5c4ac',
#  0.06607319679049439: 'f5c4ac',
#  0.06609313272778845: 'f5c4ac',
#  0.06612628083652389: 'f5c4ac',
#  0.06614593592145188: 'f5c4ac',
#  0.06616813856839864: 'f5c4ac',
#  0.06617613508503714: 'f5c4ac',
#  0.0662338566445925: 'f5c4ac',
#  0.06625216275064333: 'f5c4ac',
#  0.06629478813341735: 'f5c4ac',
#  0.06631191261132559: 'f5c4ac',
#  0.06640403695094359: 'f5c4ac',
#  ...}

# %%
g_acr2full = {"[background]":"[background]","FP":"Frontal Pole","Ins":"Insular Cortex","SFG":"Superior Frontal Gyrus","MFG":"Middle Frontal Gyrus","IFGpt":"Inferior Frontal Gyrus, pars triangularis","IFGpo":"Inferior Frontal Gyrus, pars opercularis","PrG":"Precentral Gyrus","TP":"Temporal Pole","STGa":"Superior Temporal Gyrus, anterior division","STGp":"Superior Temporal Gyrus, posterior division","MTGa":"Middle Temporal Gyrus, anterior division","MTGp":"Middle Temporal Gyrus, posterior division","MTGtp":"Middle Temporal Gyrus, temporooccipital part","ITGa":"Inferior Temporal Gyrus, anterior division","ITGp":"Inferior Temporal Gyrus, posterior division","ITGtp":"Inferior Temporal Gyrus, temporooccipital part","PoG":"Postcentral Gyrus","SPL":"Superior Parietal Lobule","SmGa":"Supramarginal Gyrus, anterior division","SmGp":"Supramarginal Gyrus, posterior division","AG":"Angular Gyrus","LOCs":"Lateral Occipital Cortex, superior division","LOCi":"Lateral Occipital Cortex, inferior division","IcC":"Intracalcarine Cortex","FMC":"Frontal Medial Cortex","SMC":"Juxtapositional Lobule Cortex","ScC":"Subcallosal Cortex","PcG":"Paracingulate Gyrus","CGa":"Cingulate Gyrus, anterior division","CGp":"Cingulate Gyrus, posterior division","PcC":"Precuneous Cortex","CC":"Cuneal Cortex","FOC":"Frontal Orbital Cortex","PhGa":"Parahippocampal Gyrus, anterior division","PaGp":"Parahippocampal Gyrus, posterior division","LG":"Lingual Gyrus","TFCa":"Temporal Fusiform Cortex, anterior division","TFCp":"Temporal Fusiform Cortex, posterior division","TOF":"Temporal Occipital Fusiform Cortex","OFG":"Occipital Fusiform Gyrus","FOpC":"Frontal Operculum Cortex","COpC":"Central Opercular Cortex","POpC":"Parietal Operculum Cortex","PP":"Planum Polare","H1\/H2":"Heschl's Gyrus (includes H1 and H2)","PT":"Planum Temporale","SccC":"Supracalcarine Cortex","OcP":"Occipital Pole","[49]":"#6A7F00","[50]":"#FFA900","[51]":"#7F5400","[52]":"#FF2A00","[53]":"#7F1500","[54]":"#FF0054","[55]":"#7F002A","[56]":"#FF00D4","[57]":"#7F006A","[58]":"#5500FF","[59]":"#2A007F"}

# %%
acronyms = OrderedDict({"[background]":"[background]","FP":"Frontal Pole","Ins":"Insular Cortex","SFG":"Superior Frontal Gyrus","MFG":"Middle Frontal Gyrus","IFGpt":"Inferior Frontal Gyrus, pars triangularis","IFGpo":"Inferior Frontal Gyrus, pars opercularis","PrG":"Precentral Gyrus","TP":"Temporal Pole","STGa":"Superior Temporal Gyrus, anterior division","STGp":"Superior Temporal Gyrus, posterior division","MTGa":"Middle Temporal Gyrus, anterior division","MTGp":"Middle Temporal Gyrus, posterior division","MTGtp":"Middle Temporal Gyrus, temporooccipital part","ITGa":"Inferior Temporal Gyrus, anterior division","ITGp":"Inferior Temporal Gyrus, posterior division","ITGtp":"Inferior Temporal Gyrus, temporooccipital part","PoG":"Postcentral Gyrus","SPL":"Superior Parietal Lobule","SmGa":"Supramarginal Gyrus, anterior division","SmGp":"Supramarginal Gyrus, posterior division","AG":"Angular Gyrus","LOCs":"Lateral Occipital Cortex, superior division","LOCi":"Lateral Occipital Cortex, inferior division","IcC":"Intracalcarine Cortex","FMC":"Frontal Medial Cortex","SMC":"Juxtapositional Lobule Cortex","ScC":"Subcallosal Cortex","PcG":"Paracingulate Gyrus","CGa":"Cingulate Gyrus, anterior division","CGp":"Cingulate Gyrus, posterior division","PcC":"Precuneous Cortex","CC":"Cuneal Cortex","FOC":"Frontal Orbital Cortex","PhGa":"Parahippocampal Gyrus, anterior division","PaGp":"Parahippocampal Gyrus, posterior division","LG":"Lingual Gyrus","TFCa":"Temporal Fusiform Cortex, anterior division","TFCp":"Temporal Fusiform Cortex, posterior division","TOF":"Temporal Occipital Fusiform Cortex","OFG":"Occipital Fusiform Gyrus","FOpC":"Frontal Operculum Cortex","COpC":"Central Opercular Cortex","POpC":"Parietal Operculum Cortex","PP":"Planum Polare","H1\/H2":"Heschl's Gyrus (includes H1 and H2)","PT":"Planum Temporale","SccC":"Supracalcarine Cortex","OcP":"Occipital Pole","[49]":"#6A7F00","[50]":"#FFA900","[51]":"#7F5400","[52]":"#FF2A00","[53]":"#7F1500","[54]":"#FF0054","[55]":"#7F002A","[56]":"#FF00D4","[57]":"#7F006A","[58]":"#5500FF","[59]":"#2A007F"})
acronyms = list(full_names.keys())[1:49]

# %%
var_names = activations.columns
var_names = [var.replace("left_", "") for var in activations.columns if var.startswith("left")][:-9]
var2acr = {var_names[i]: acronyms[i] for i in range(len(acronyms))}
var2acr
# Out:
# {'frontal_pole': 'FP',
#  'insular_cortex': 'Ins',
#  'superior_frontal_gyrus': 'SFG',
#  'middle_frontal_gyrus': 'MFG',
#  'inferior_frontal_gyrus_pars_triangularis': 'IFGpt',
#  'inferior_frontal_gyrus_pars_opercularis': 'IFGpo',
#  'precentral_gyrus': 'PrG',
#  'temporal_pole': 'TP',
#  'superior_temporal_gyrus_anterior_division': 'STGa',
#  'superior_temporal_gyrus_posterior_division': 'STGp',
#  'middle_temporal_gyrus_anterior_division': 'MTGa',
#  'middle_temporal_gyrus_posterior_division': 'MTGp',
#  'middle_temporal_gyrus_temporooccipital_part': 'MTGtp',
#  'inferior_temporal_gyrus_anterior_division': 'ITGa',
#  'inferior_temporal_gyrus_posterior_division': 'ITGp',
#  'inferior_temporal_gyrus_temporooccipital_part': 'ITGtp',
#  'postcentral_gyrus': 'PoG',
#  'superior_parietal_lobule': 'SPL',
#  'supramarginal_gyrus_anterior_division': 'SmGa',
#  'supramarginal_gyrus_posterior_division': 'SmGp',
#  'angular_gyrus': 'AG',
#  'lateral_occipital_cortex_superior_division': 'LOCs',
#  'lateral_occipital_cortex_inferior_division': 'LOCi',
#  'intracalcarine_cortex': 'IcC',
#  'frontal_medial_cortex': 'FMC',
#  'supplementary_motor_cortex': 'SMC',
#  'subcallosal_cortex': 'ScC',
#  'paracingulate_gyrus': 'PcG',
#  'cingulate_gyrus_anterior_division': 'CGa',
#  'cingulate_gyrus_posterior_division': 'CGp',
#  'precuneous_cortex': 'PcC',
#  'cuneal_cortex': 'CC',
#  'frontal_orbital_cortex': 'FOC',
#  'parahippocampal_gyrus_anterior_division': 'PhGa',
#  'parahippocampal_gyrus_posterior_division': 'PaGp',
#  'lingual_gyrus': 'LG',
#  'temporal_fusiform_cortex_anterior_division': 'TFCa',
#  'temporal_fusiform_cortex_posterior_division': 'TFCp',
#  'temporal_occipital_fusiform_cortex': 'TOF',
#  'occipital_fusiform_gyrus': 'OFG',
#  'frontal_operculum_cortex': 'FOpC',
#  'central_opercular_cortex': 'COpC',
#  'parietal_operculum_cortex': 'POpC',
#  'planum_polare': 'PP',
#  'heschls_gyrus': 'H1\\/H2',
#  'planum_temporale': 'PT',
#  'supracalcarine_cortex': 'SccC',
#  'occipital_pole': 'OcP'}

# %%
left_vars = [var for var in R.index if var.startswith("left_")]
R_left = R.loc[R.index.isin(left_vars)]
R_left.index = [var.replace("left_", "") for var in R_left.index]
R_left = R_left.loc[R_left.index.isin(var_names)]
R_left
# Out:
#                                                ACUTE_THREAT  POTENTIAL_THREAT  \
# frontal_pole                                       0.000000          0.000000
# insular_cortex                                     0.078857          0.038196
# superior_frontal_gyrus                             0.000000         -0.047947
# middle_frontal_gyrus                              -0.079399         -0.079588
# inferior_frontal_gyrus_pars_triangularis           0.000000          0.000000
# inferior_frontal_gyrus_pars_opercularis           -0.052793         -0.065947
# precentral_gyrus                                  -0.058074         -0.085329
# temporal_pole                                      0.062941          0.045818
# superior_temporal_gyrus_anterior_division          0.000000          0.000000
# superior_temporal_gyrus_posterior_division        -0.040396         -0.066326
# middle_temporal_gyrus_anterior_division            0.000000         -0.036928
# middle_temporal_gyrus_posterior_division          -0.039747         -0.058113
# middle_temporal_gyrus_temporooccipital_part       -0.052734         -0.075897
# inferior_temporal_gyrus_anterior_division          0.000000          0.000000
# inferior_temporal_gyrus_posterior_division         0.000000          0.000000
# inferior_temporal_gyrus_temporooccipital_part     -0.054258         -0.061995
# postcentral_gyrus                                  0.000000         -0.074203
# superior_parietal_lobule                          -0.096056         -0.104473
# supramarginal_gyrus_anterior_division             -0.044466         -0.075598
# supramarginal_gyrus_posterior_division            -0.084705         -0.108815
# angular_gyrus                                     -0.073295         -0.083724
# lateral_occipital_cortex_superior_division        -0.096836         -0.095566
# lateral_occipital_cortex_inferior_division        -0.059664         -0.066229
# intracalcarine_cortex                              0.000000          0.000000
# frontal_medial_cortex                              0.073516          0.062262
# supplementary_motor_cortex                         0.000000         -0.057046
# subcallosal_cortex                                 0.075780          0.053408
# paracingulate_gyrus                                0.043159          0.000000
# cingulate_gyrus_anterior_division                  0.060011          0.000000
# cingulate_gyrus_posterior_division                 0.000000          0.000000
# precuneous_cortex                                 -0.043643          0.000000
# cuneal_cortex                                      0.000000          0.000000
# frontal_orbital_cortex                             0.045050          0.000000
# parahippocampal_gyrus_anterior_division            0.095678          0.104630
# parahippocampal_gyrus_posterior_division           0.000000          0.000000
# lingual_gyrus                                      0.000000          0.000000
# temporal_fusiform_cortex_anterior_division         0.000000          0.000000
# temporal_fusiform_cortex_posterior_division        0.000000          0.000000
# temporal_occipital_fusiform_cortex                 0.000000         -0.041664
# occipital_fusiform_gyrus                          -0.040507         -0.053868
# frontal_operculum_cortex                           0.000000          0.000000
# central_opercular_cortex                           0.046721          0.000000
# parietal_operculum_cortex                          0.000000         -0.041220
# planum_polare                                      0.000000          0.000000
# heschls_gyrus                                      0.000000          0.000000
# planum_temporale                                   0.000000         -0.054699
# supracalcarine_cortex                              0.000000          0.000000
# occipital_pole                                    -0.049077         -0.051793
#
#                                                SUSTAINED_THREAT      LOSS  \
# frontal_pole                                           0.000000  0.038411
# insular_cortex                                         0.000000  0.050793
# superior_frontal_gyrus                                 0.000000 -0.052740
# middle_frontal_gyrus                                  -0.043650 -0.105278
# inferior_frontal_gyrus_pars_triangularis               0.000000 -0.043649
# inferior_frontal_gyrus_pars_opercularis               -0.048247 -0.089065
# precentral_gyrus                                      -0.055518 -0.099748
# temporal_pole                                          0.000000  0.054710
# superior_temporal_gyrus_anterior_division             -0.040137  0.000000
# superior_temporal_gyrus_posterior_division            -0.069454 -0.051205
# middle_temporal_gyrus_anterior_division               -0.037173  0.000000
# middle_temporal_gyrus_posterior_division              -0.043289 -0.036419
# middle_temporal_gyrus_temporooccipital_part           -0.055530 -0.080863
# inferior_temporal_gyrus_anterior_division              0.000000  0.000000
# inferior_temporal_gyrus_posterior_division             0.000000  0.000000
# inferior_temporal_gyrus_temporooccipital_part         -0.045459 -0.082847
# postcentral_gyrus                                     -0.050803 -0.076723
# superior_parietal_lobule                              -0.068687 -0.126764
# supramarginal_gyrus_anterior_division                 -0.057846 -0.094047
# supramarginal_gyrus_posterior_division                -0.070439 -0.112573
# angular_gyrus                                         -0.060753 -0.096086
# lateral_occipital_cortex_superior_division            -0.059897 -0.111335
# lateral_occipital_cortex_inferior_division            -0.053256 -0.095494
# intracalcarine_cortex                                  0.000000  0.000000
# frontal_medial_cortex                                  0.042150  0.089680
# supplementary_motor_cortex                            -0.043420 -0.055252
# subcallosal_cortex                                     0.077843  0.093978
# paracingulate_gyrus                                    0.000000  0.000000
# cingulate_gyrus_anterior_division                      0.000000  0.042702
# cingulate_gyrus_posterior_division                     0.000000  0.000000
# precuneous_cortex                                      0.000000 -0.036731
# cuneal_cortex                                          0.000000  0.000000
# frontal_orbital_cortex                                 0.000000  0.000000
# parahippocampal_gyrus_anterior_division                0.000000  0.093371
# parahippocampal_gyrus_posterior_division               0.000000  0.000000
# lingual_gyrus                                          0.000000 -0.037351
# temporal_fusiform_cortex_anterior_division             0.000000  0.000000
# temporal_fusiform_cortex_posterior_division            0.000000  0.000000
# temporal_occipital_fusiform_cortex                    -0.043521 -0.071541
# occipital_fusiform_gyrus                              -0.038475 -0.081586
# frontal_operculum_cortex                               0.000000  0.000000
# central_opercular_cortex                               0.000000  0.000000
# parietal_operculum_cortex                             -0.054290 -0.041374
# planum_polare                                          0.000000  0.000000
# heschls_gyrus                                          0.000000  0.000000
# planum_temporale                                      -0.056861 -0.050529
# supracalcarine_cortex                                  0.000000  0.000000
# occipital_pole                                         0.000000 -0.076618
#
#                                                FRUSTRATIVE_NONREWARD  \
# frontal_pole                                                 0.00000
# insular_cortex                                               0.00000
# superior_frontal_gyrus                                       0.00000
# middle_frontal_gyrus                                         0.00000
# inferior_frontal_gyrus_pars_triangularis                     0.00000
# inferior_frontal_gyrus_pars_opercularis                      0.00000
# precentral_gyrus                                             0.00000
# temporal_pole                                                0.00000
# superior_temporal_gyrus_anterior_division                    0.00000
# superior_temporal_gyrus_posterior_division                   0.00000
# middle_temporal_gyrus_anterior_division                      0.00000
# middle_temporal_gyrus_posterior_division                     0.00000
# middle_temporal_gyrus_temporooccipital_part                  0.00000
# inferior_temporal_gyrus_anterior_division                    0.00000
# inferior_temporal_gyrus_posterior_division                   0.00000
# inferior_temporal_gyrus_temporooccipital_part                0.00000
# postcentral_gyrus                                            0.00000
# superior_parietal_lobule                                     0.00000
# supramarginal_gyrus_anterior_division                        0.00000
# supramarginal_gyrus_posterior_division                       0.00000
# angular_gyrus                                                0.00000
# lateral_occipital_cortex_superior_division                   0.00000
# lateral_occipital_cortex_inferior_division                   0.00000
# intracalcarine_cortex                                        0.00000
# frontal_medial_cortex                                        0.00000
# supplementary_motor_cortex                                   0.00000
# subcallosal_cortex                                           0.04865
# paracingulate_gyrus                                          0.00000
# cingulate_gyrus_anterior_division                            0.00000
# cingulate_gyrus_posterior_division                           0.00000
# precuneous_cortex                                            0.00000
# cuneal_cortex                                                0.00000
# frontal_orbital_cortex                                       0.00000
# parahippocampal_gyrus_anterior_division                      0.00000
# parahippocampal_gyrus_posterior_division                     0.00000
# lingual_gyrus                                                0.00000
# temporal_fusiform_cortex_anterior_division                   0.00000
# temporal_fusiform_cortex_posterior_division                  0.00000
# temporal_occipital_fusiform_cortex                           0.00000
# occipital_fusiform_gyrus                                     0.00000
# frontal_operculum_cortex                                     0.00000
# central_opercular_cortex                                     0.00000
# parietal_operculum_cortex                                    0.00000
# planum_polare                                                0.00000
# heschls_gyrus                                                0.00000
# planum_temporale                                             0.00000
# supracalcarine_cortex                                        0.00000
# occipital_pole                                               0.00000
#
#                                                REWARD_ANTICIPATION  \
# frontal_pole                                              0.063298
# insular_cortex                                            0.081867
# superior_frontal_gyrus                                    0.000000
# middle_frontal_gyrus                                      0.000000
# inferior_frontal_gyrus_pars_triangularis                  0.000000
# inferior_frontal_gyrus_pars_opercularis                  -0.048873
# precentral_gyrus                                         -0.051955
# temporal_pole                                             0.000000
# superior_temporal_gyrus_anterior_division                -0.041448
# superior_temporal_gyrus_posterior_division               -0.074294
# middle_temporal_gyrus_anterior_division                  -0.044060
# middle_temporal_gyrus_posterior_division                 -0.058353
# middle_temporal_gyrus_temporooccipital_part              -0.063925
# inferior_temporal_gyrus_anterior_division                 0.000000
# inferior_temporal_gyrus_posterior_division               -0.042350
# inferior_temporal_gyrus_temporooccipital_part            -0.059277
# postcentral_gyrus                                        -0.045484
# superior_parietal_lobule                                 -0.068276
# supramarginal_gyrus_anterior_division                    -0.055388
# supramarginal_gyrus_posterior_division                   -0.072641
# angular_gyrus                                            -0.058331
# lateral_occipital_cortex_superior_division               -0.067801
# lateral_occipital_cortex_inferior_division               -0.056162
# intracalcarine_cortex                                     0.000000
# frontal_medial_cortex                                     0.100077
# supplementary_motor_cortex                                0.000000
# subcallosal_cortex                                        0.166546
# paracingulate_gyrus                                       0.058955
# cingulate_gyrus_anterior_division                         0.073427
# cingulate_gyrus_posterior_division                        0.000000
# precuneous_cortex                                         0.000000
# cuneal_cortex                                             0.000000
# frontal_orbital_cortex                                    0.071737
# parahippocampal_gyrus_anterior_division                   0.046330
# parahippocampal_gyrus_posterior_division                  0.000000
# lingual_gyrus                                             0.000000
# temporal_fusiform_cortex_anterior_division                0.000000
# temporal_fusiform_cortex_posterior_division              -0.045629
# temporal_occipital_fusiform_cortex                       -0.057878
# occipital_fusiform_gyrus                                 -0.040580
# frontal_operculum_cortex                                  0.000000
# central_opercular_cortex                                  0.000000
# parietal_operculum_cortex                                -0.048146
# planum_polare                                             0.000000
# heschls_gyrus                                             0.000000
# planum_temporale                                         -0.058695
# supracalcarine_cortex                                     0.000000
# occipital_pole                                            0.000000
#
#                                                INITIAL_REWARD_RESPONSIVENESS  \
# frontal_pole                                                        0.077857
# insular_cortex                                                      0.072431
# superior_frontal_gyrus                                              0.000000
# middle_frontal_gyrus                                                0.000000
# inferior_frontal_gyrus_pars_triangularis                            0.000000
# inferior_frontal_gyrus_pars_opercularis                            -0.043382
# precentral_gyrus                                                   -0.059838
# temporal_pole                                                       0.000000
# superior_temporal_gyrus_anterior_division                           0.000000
# superior_temporal_gyrus_posterior_division                         -0.067673
# middle_temporal_gyrus_anterior_division                             0.000000
# middle_temporal_gyrus_posterior_division                           -0.045454
# middle_temporal_gyrus_temporooccipital_part                        -0.055602
# inferior_temporal_gyrus_anterior_division                           0.000000
# inferior_temporal_gyrus_posterior_division                          0.000000
# inferior_temporal_gyrus_temporooccipital_part                      -0.052044
# postcentral_gyrus                                                  -0.064222
# superior_parietal_lobule                                           -0.071580
# supramarginal_gyrus_anterior_division                              -0.060611
# supramarginal_gyrus_posterior_division                             -0.067171
# angular_gyrus                                                      -0.051786
# lateral_occipital_cortex_superior_division                         -0.054385
# lateral_occipital_cortex_inferior_division                         -0.048511
# intracalcarine_cortex                                               0.000000
# frontal_medial_cortex                                               0.109769
# supplementary_motor_cortex                                         -0.037453
# subcallosal_cortex                                                  0.152233
# paracingulate_gyrus                                                 0.064779
# cingulate_gyrus_anterior_division                                   0.067177
# cingulate_gyrus_posterior_division                                  0.000000
# precuneous_cortex                                                   0.000000
# cuneal_cortex                                                       0.000000
# frontal_orbital_cortex                                              0.082217
# parahippocampal_gyrus_anterior_division                             0.052327
# parahippocampal_gyrus_posterior_division                            0.000000
# lingual_gyrus                                                       0.000000
# temporal_fusiform_cortex_anterior_division                          0.000000
# temporal_fusiform_cortex_posterior_division                         0.000000
# temporal_occipital_fusiform_cortex                                 -0.056529
# occipital_fusiform_gyrus                                           -0.043041
# frontal_operculum_cortex                                            0.000000
# central_opercular_cortex                                            0.000000
# parietal_operculum_cortex                                          -0.049044
# planum_polare                                                       0.000000
# heschls_gyrus                                                      -0.037610
# planum_temporale                                                   -0.061612
# supracalcarine_cortex                                               0.000000
# occipital_pole                                                      0.000000
#
#                                                REWARD_SATIATION  \
# frontal_pole                                           0.079142
# insular_cortex                                         0.076654
# superior_frontal_gyrus                                 0.000000
# middle_frontal_gyrus                                   0.000000
# inferior_frontal_gyrus_pars_triangularis               0.000000
# inferior_frontal_gyrus_pars_opercularis               -0.044489
# precentral_gyrus                                      -0.060336
# temporal_pole                                          0.000000
# superior_temporal_gyrus_anterior_division              0.000000
# superior_temporal_gyrus_posterior_division            -0.067987
# middle_temporal_gyrus_anterior_division                0.000000
# middle_temporal_gyrus_posterior_division              -0.046703
# middle_temporal_gyrus_temporooccipital_part           -0.055633
# inferior_temporal_gyrus_anterior_division              0.000000
# inferior_temporal_gyrus_posterior_division             0.000000
# inferior_temporal_gyrus_temporooccipital_part         -0.050991
# postcentral_gyrus                                     -0.059521
# superior_parietal_lobule                              -0.069519
# supramarginal_gyrus_anterior_division                 -0.059535
# supramarginal_gyrus_posterior_division                -0.065735
# angular_gyrus                                         -0.049054
# lateral_occipital_cortex_superior_division            -0.053387
# lateral_occipital_cortex_inferior_division            -0.048728
# intracalcarine_cortex                                  0.000000
# frontal_medial_cortex                                  0.110485
# supplementary_motor_cortex                             0.000000
# subcallosal_cortex                                     0.154865
# paracingulate_gyrus                                    0.066093
# cingulate_gyrus_anterior_division                      0.068813
# cingulate_gyrus_posterior_division                     0.000000
# precuneous_cortex                                      0.000000
# cuneal_cortex                                          0.000000
# frontal_orbital_cortex                                 0.081571
# parahippocampal_gyrus_anterior_division                0.053181
# parahippocampal_gyrus_posterior_division               0.000000
# lingual_gyrus                                          0.000000
# temporal_fusiform_cortex_anterior_division             0.000000
# temporal_fusiform_cortex_posterior_division            0.000000
# temporal_occipital_fusiform_cortex                    -0.053684
# occipital_fusiform_gyrus                              -0.043965
# frontal_operculum_cortex                               0.000000
# central_opercular_cortex                               0.000000
# parietal_operculum_cortex                             -0.047715
# planum_polare                                          0.000000
# heschls_gyrus                                          0.000000
# planum_temporale                                      -0.060160
# supracalcarine_cortex                                  0.000000
# occipital_pole                                         0.000000
#
#                                                REINFORCEMENT_LEARNING  \
# frontal_pole                                                 0.063215
# insular_cortex                                               0.063565
# superior_frontal_gyrus                                       0.000000
# middle_frontal_gyrus                                         0.000000
# inferior_frontal_gyrus_pars_triangularis                     0.000000
# inferior_frontal_gyrus_pars_opercularis                     -0.040350
# precentral_gyrus                                            -0.050668
# temporal_pole                                                0.000000
# superior_temporal_gyrus_anterior_division                   -0.038078
# superior_temporal_gyrus_posterior_division                  -0.069223
# middle_temporal_gyrus_anterior_division                     -0.036435
# middle_temporal_gyrus_posterior_division                    -0.047666
# middle_temporal_gyrus_temporooccipital_part                 -0.061760
# inferior_temporal_gyrus_anterior_division                    0.000000
# inferior_temporal_gyrus_posterior_division                   0.000000
# inferior_temporal_gyrus_temporooccipital_part               -0.050431
# postcentral_gyrus                                           -0.058036
# superior_parietal_lobule                                    -0.058324
# supramarginal_gyrus_anterior_division                       -0.049595
# supramarginal_gyrus_posterior_division                      -0.054779
# angular_gyrus                                               -0.039194
# lateral_occipital_cortex_superior_division                  -0.048946
# lateral_occipital_cortex_inferior_division                  -0.046877
# intracalcarine_cortex                                        0.000000
# frontal_medial_cortex                                        0.108349
# supplementary_motor_cortex                                   0.000000
# subcallosal_cortex                                           0.156005
# paracingulate_gyrus                                          0.066312
# cingulate_gyrus_anterior_division                            0.062868
# cingulate_gyrus_posterior_division                           0.000000
# precuneous_cortex                                            0.000000
# cuneal_cortex                                                0.000000
# frontal_orbital_cortex                                       0.080126
# parahippocampal_gyrus_anterior_division                      0.036791
# parahippocampal_gyrus_posterior_division                     0.000000
# lingual_gyrus                                                0.000000
# temporal_fusiform_cortex_anterior_division                   0.000000
# temporal_fusiform_cortex_posterior_division                 -0.039342
# temporal_occipital_fusiform_cortex                          -0.054712
# occipital_fusiform_gyrus                                    -0.037770
# frontal_operculum_cortex                                     0.000000
# central_opercular_cortex                                     0.000000
# parietal_operculum_cortex                                   -0.051355
# planum_polare                                                0.000000
# heschls_gyrus                                               -0.037985
# planum_temporale                                            -0.061066
# supracalcarine_cortex                                        0.000000
# occipital_pole                                               0.000000
#
#                                                REWARD_PREDICTION_ERROR  \
# frontal_pole                                                  0.061135
# insular_cortex                                                0.064978
# superior_frontal_gyrus                                        0.000000
# middle_frontal_gyrus                                          0.000000
# inferior_frontal_gyrus_pars_triangularis                      0.000000
# inferior_frontal_gyrus_pars_opercularis                      -0.038532
# precentral_gyrus                                             -0.047361
# temporal_pole                                                 0.000000
# superior_temporal_gyrus_anterior_division                     0.000000
# superior_temporal_gyrus_posterior_division                   -0.062800
# middle_temporal_gyrus_anterior_division                       0.000000
# middle_temporal_gyrus_posterior_division                     -0.038784
# middle_temporal_gyrus_temporooccipital_part                  -0.055066
# inferior_temporal_gyrus_anterior_division                     0.000000
# inferior_temporal_gyrus_posterior_division                    0.000000
# inferior_temporal_gyrus_temporooccipital_part                -0.043157
# postcentral_gyrus                                            -0.053435
# superior_parietal_lobule                                     -0.056417
# supramarginal_gyrus_anterior_division                        -0.048588
# supramarginal_gyrus_posterior_division                       -0.050951
# angular_gyrus                                                -0.038200
# lateral_occipital_cortex_superior_division                   -0.045039
# lateral_occipital_cortex_inferior_division                   -0.038781
# intracalcarine_cortex                                         0.000000
# frontal_medial_cortex                                         0.109828
# supplementary_motor_cortex                                    0.000000
# subcallosal_cortex                                            0.162992
# paracingulate_gyrus                                           0.061481
# cingulate_gyrus_anterior_division                             0.061075
# cingulate_gyrus_posterior_division                            0.000000
# precuneous_cortex                                             0.000000
# cuneal_cortex                                                 0.000000
# frontal_orbital_cortex                                        0.079140
# parahippocampal_gyrus_anterior_division                       0.036522
# parahippocampal_gyrus_posterior_division                      0.000000
# lingual_gyrus                                                 0.000000
# temporal_fusiform_cortex_anterior_division                    0.000000
# temporal_fusiform_cortex_posterior_division                   0.000000
# temporal_occipital_fusiform_cortex                           -0.047622
# occipital_fusiform_gyrus                                      0.000000
# frontal_operculum_cortex                                      0.000000
# central_opercular_cortex                                      0.000000
# parietal_operculum_cortex                                    -0.043464
# planum_polare                                                 0.000000
# heschls_gyrus                                                 0.000000
# planum_temporale                                             -0.054074
# supracalcarine_cortex                                         0.000000
# occipital_pole                                                0.000000
#
#                                                      ...          \
# frontal_pole                                         ...
# insular_cortex                                       ...
# superior_frontal_gyrus                               ...
# middle_frontal_gyrus                                 ...
# inferior_frontal_gyrus_pars_triangularis             ...
# inferior_frontal_gyrus_pars_opercularis              ...
# precentral_gyrus                                     ...
# temporal_pole                                        ...
# superior_temporal_gyrus_anterior_division            ...
# superior_temporal_gyrus_posterior_division           ...
# middle_temporal_gyrus_anterior_division              ...
# middle_temporal_gyrus_posterior_division             ...
# middle_temporal_gyrus_temporooccipital_part          ...
# inferior_temporal_gyrus_anterior_division            ...
# inferior_temporal_gyrus_posterior_division           ...
# inferior_temporal_gyrus_temporooccipital_part        ...
# postcentral_gyrus                                    ...
# superior_parietal_lobule                             ...
# supramarginal_gyrus_anterior_division                ...
# supramarginal_gyrus_posterior_division               ...
# angular_gyrus                                        ...
# lateral_occipital_cortex_superior_division           ...
# lateral_occipital_cortex_inferior_division           ...
# intracalcarine_cortex                                ...
# frontal_medial_cortex                                ...
# supplementary_motor_cortex                           ...
# subcallosal_cortex                                   ...
# paracingulate_gyrus                                  ...
# cingulate_gyrus_anterior_division                    ...
# cingulate_gyrus_posterior_division                   ...
# precuneous_cortex                                    ...
# cuneal_cortex                                        ...
# frontal_orbital_cortex                               ...
# parahippocampal_gyrus_anterior_division              ...
# parahippocampal_gyrus_posterior_division             ...
# lingual_gyrus                                        ...
# temporal_fusiform_cortex_anterior_division           ...
# temporal_fusiform_cortex_posterior_division          ...
# temporal_occipital_fusiform_cortex                   ...
# occipital_fusiform_gyrus                             ...
# frontal_operculum_cortex                             ...
# central_opercular_cortex                             ...
# parietal_operculum_cortex                            ...
# planum_polare                                        ...
# heschls_gyrus                                        ...
# planum_temporale                                     ...
# supracalcarine_cortex                                ...
# occipital_pole                                       ...
#
#                                                NONFACIAL_COMM_RECEPTION  \
# frontal_pole                                                   0.000000
# insular_cortex                                                 0.000000
# superior_frontal_gyrus                                         0.000000
# middle_frontal_gyrus                                           0.000000
# inferior_frontal_gyrus_pars_triangularis                       0.000000
# inferior_frontal_gyrus_pars_opercularis                        0.000000
# precentral_gyrus                                               0.000000
# temporal_pole                                                  0.037615
# superior_temporal_gyrus_anterior_division                      0.000000
# superior_temporal_gyrus_posterior_division                     0.000000
# middle_temporal_gyrus_anterior_division                        0.000000
# middle_temporal_gyrus_posterior_division                       0.000000
# middle_temporal_gyrus_temporooccipital_part                    0.041685
# inferior_temporal_gyrus_anterior_division                      0.000000
# inferior_temporal_gyrus_posterior_division                     0.000000
# inferior_temporal_gyrus_temporooccipital_part                  0.040470
# postcentral_gyrus                                              0.000000
# superior_parietal_lobule                                       0.000000
# supramarginal_gyrus_anterior_division                          0.000000
# supramarginal_gyrus_posterior_division                         0.000000
# angular_gyrus                                                  0.000000
# lateral_occipital_cortex_superior_division                     0.000000
# lateral_occipital_cortex_inferior_division                     0.053963
# intracalcarine_cortex                                          0.000000
# frontal_medial_cortex                                          0.000000
# supplementary_motor_cortex                                     0.000000
# subcallosal_cortex                                             0.000000
# paracingulate_gyrus                                            0.000000
# cingulate_gyrus_anterior_division                              0.000000
# cingulate_gyrus_posterior_division                             0.000000
# precuneous_cortex                                              0.000000
# cuneal_cortex                                                  0.000000
# frontal_orbital_cortex                                         0.000000
# parahippocampal_gyrus_anterior_division                        0.036867
# parahippocampal_gyrus_posterior_division                       0.000000
# lingual_gyrus                                                  0.000000
# temporal_fusiform_cortex_anterior_division                     0.000000
# temporal_fusiform_cortex_posterior_division                    0.000000
# temporal_occipital_fusiform_cortex                             0.000000
# occipital_fusiform_gyrus                                       0.000000
# frontal_operculum_cortex                                       0.000000
# central_opercular_cortex                                       0.000000
# parietal_operculum_cortex                                      0.000000
# planum_polare                                                  0.000000
# heschls_gyrus                                                  0.000000
# planum_temporale                                               0.000000
# supracalcarine_cortex                                          0.000000
# occipital_pole                                                 0.000000
#
#                                                NONFACIAL_COMM_PRODUCTION  \
# frontal_pole                                                    0.000000
# insular_cortex                                                  0.000000
# superior_frontal_gyrus                                          0.000000
# middle_frontal_gyrus                                            0.000000
# inferior_frontal_gyrus_pars_triangularis                        0.000000
# inferior_frontal_gyrus_pars_opercularis                         0.000000
# precentral_gyrus                                                0.000000
# temporal_pole                                                   0.056124
# superior_temporal_gyrus_anterior_division                       0.070624
# superior_temporal_gyrus_posterior_division                      0.059664
# middle_temporal_gyrus_anterior_division                         0.060309
# middle_temporal_gyrus_posterior_division                        0.064921
# middle_temporal_gyrus_temporooccipital_part                     0.039974
# inferior_temporal_gyrus_anterior_division                       0.000000
# inferior_temporal_gyrus_posterior_division                      0.000000
# inferior_temporal_gyrus_temporooccipital_part                   0.000000
# postcentral_gyrus                                               0.000000
# superior_parietal_lobule                                       -0.039674
# supramarginal_gyrus_anterior_division                           0.000000
# supramarginal_gyrus_posterior_division                          0.000000
# angular_gyrus                                                   0.000000
# lateral_occipital_cortex_superior_division                      0.000000
# lateral_occipital_cortex_inferior_division                      0.000000
# intracalcarine_cortex                                           0.000000
# frontal_medial_cortex                                           0.000000
# supplementary_motor_cortex                                      0.000000
# subcallosal_cortex                                              0.000000
# paracingulate_gyrus                                             0.000000
# cingulate_gyrus_anterior_division                               0.000000
# cingulate_gyrus_posterior_division                              0.000000
# precuneous_cortex                                               0.000000
# cuneal_cortex                                                   0.000000
# frontal_orbital_cortex                                          0.037470
# parahippocampal_gyrus_anterior_division                         0.038727
# parahippocampal_gyrus_posterior_division                        0.000000
# lingual_gyrus                                                   0.000000
# temporal_fusiform_cortex_anterior_division                      0.000000
# temporal_fusiform_cortex_posterior_division                     0.000000
# temporal_occipital_fusiform_cortex                              0.000000
# occipital_fusiform_gyrus                                        0.000000
# frontal_operculum_cortex                                        0.036374
# central_opercular_cortex                                        0.000000
# parietal_operculum_cortex                                       0.000000
# planum_polare                                                   0.043377
# heschls_gyrus                                                   0.039346
# planum_temporale                                                0.046278
# supracalcarine_cortex                                           0.000000
# occipital_pole                                                  0.000000
#
#                                                 AGENCY  SELF_KNOWLEDGE  \
# frontal_pole                                   0.00000        0.049282
# insular_cortex                                 0.00000        0.000000
# superior_frontal_gyrus                         0.00000        0.036611
# middle_frontal_gyrus                           0.00000        0.000000
# inferior_frontal_gyrus_pars_triangularis       0.00000        0.000000
# inferior_frontal_gyrus_pars_opercularis        0.00000        0.000000
# precentral_gyrus                               0.00000        0.000000
# temporal_pole                                  0.00000        0.038980
# superior_temporal_gyrus_anterior_division      0.00000        0.000000
# superior_temporal_gyrus_posterior_division     0.00000        0.000000
# middle_temporal_gyrus_anterior_division        0.00000        0.000000
# middle_temporal_gyrus_posterior_division       0.00000        0.000000
# middle_temporal_gyrus_temporooccipital_part    0.00000        0.000000
# inferior_temporal_gyrus_anterior_division      0.00000        0.000000
# inferior_temporal_gyrus_posterior_division     0.00000        0.000000
# inferior_temporal_gyrus_temporooccipital_part  0.00000        0.000000
# postcentral_gyrus                              0.00000        0.000000
# superior_parietal_lobule                       0.00000        0.000000
# supramarginal_gyrus_anterior_division          0.00000        0.000000
# supramarginal_gyrus_posterior_division         0.00000        0.000000
# angular_gyrus                                  0.00000        0.000000
# lateral_occipital_cortex_superior_division     0.00000        0.000000
# lateral_occipital_cortex_inferior_division     0.00000        0.000000
# intracalcarine_cortex                          0.00000        0.000000
# frontal_medial_cortex                          0.03818        0.066176
# supplementary_motor_cortex                     0.00000        0.000000
# subcallosal_cortex                             0.00000        0.000000
# paracingulate_gyrus                            0.00000        0.054394
# cingulate_gyrus_anterior_division              0.00000        0.000000
# cingulate_gyrus_posterior_division             0.00000        0.041254
# precuneous_cortex                              0.00000        0.000000
# cuneal_cortex                                  0.00000        0.000000
# frontal_orbital_cortex                         0.00000        0.039715
# parahippocampal_gyrus_anterior_division        0.00000        0.000000
# parahippocampal_gyrus_posterior_division       0.00000        0.000000
# lingual_gyrus                                  0.00000        0.000000
# temporal_fusiform_cortex_anterior_division     0.00000        0.000000
# temporal_fusiform_cortex_posterior_division    0.00000        0.000000
# temporal_occipital_fusiform_cortex             0.00000        0.000000
# occipital_fusiform_gyrus                       0.00000        0.000000
# frontal_operculum_cortex                       0.00000        0.000000
# central_opercular_cortex                       0.00000        0.000000
# parietal_operculum_cortex                      0.00000        0.000000
# planum_polare                                  0.00000        0.000000
# heschls_gyrus                                  0.00000        0.000000
# planum_temporale                               0.00000        0.000000
# supracalcarine_cortex                          0.00000        0.000000
# occipital_pole                                 0.00000        0.000000
#
#                                                ANIMACY_PERCEPTION  \
# frontal_pole                                             0.000000
# insular_cortex                                           0.000000
# superior_frontal_gyrus                                   0.000000
# middle_frontal_gyrus                                     0.000000
# inferior_frontal_gyrus_pars_triangularis                 0.000000
# inferior_frontal_gyrus_pars_opercularis                  0.000000
# precentral_gyrus                                         0.000000
# temporal_pole                                            0.000000
# superior_temporal_gyrus_anterior_division                0.000000
# superior_temporal_gyrus_posterior_division               0.036769
# middle_temporal_gyrus_anterior_division                  0.038017
# middle_temporal_gyrus_posterior_division                 0.040684
# middle_temporal_gyrus_temporooccipital_part              0.054272
# inferior_temporal_gyrus_anterior_division                0.000000
# inferior_temporal_gyrus_posterior_division               0.000000
# inferior_temporal_gyrus_temporooccipital_part            0.000000
# postcentral_gyrus                                        0.000000
# superior_parietal_lobule                                 0.000000
# supramarginal_gyrus_anterior_division                    0.000000
# supramarginal_gyrus_posterior_division                   0.040470
# angular_gyrus                                            0.046372
# lateral_occipital_cortex_superior_division               0.000000
# lateral_occipital_cortex_inferior_division               0.037955
# intracalcarine_cortex                                    0.000000
# frontal_medial_cortex                                    0.000000
# supplementary_motor_cortex                               0.000000
# subcallosal_cortex                                       0.000000
# paracingulate_gyrus                                      0.000000
# cingulate_gyrus_anterior_division                        0.000000
# cingulate_gyrus_posterior_division                       0.000000
# precuneous_cortex                                        0.000000
# cuneal_cortex                                            0.000000
# frontal_orbital_cortex                                   0.000000
# parahippocampal_gyrus_anterior_division                  0.000000
# parahippocampal_gyrus_posterior_division                 0.000000
# lingual_gyrus                                            0.000000
# temporal_fusiform_cortex_anterior_division               0.000000
# temporal_fusiform_cortex_posterior_division              0.000000
# temporal_occipital_fusiform_cortex                       0.000000
# occipital_fusiform_gyrus                                 0.000000
# frontal_operculum_cortex                                 0.000000
# central_opercular_cortex                                 0.000000
# parietal_operculum_cortex                                0.000000
# planum_polare                                            0.000000
# heschls_gyrus                                            0.000000
# planum_temporale                                         0.000000
# supracalcarine_cortex                                    0.000000
# occipital_pole                                           0.000000
#
#                                                ACTION_PERCEPTION  \
# frontal_pole                                            0.000000
# insular_cortex                                          0.000000
# superior_frontal_gyrus                                  0.096030
# middle_frontal_gyrus                                    0.085275
# inferior_frontal_gyrus_pars_triangularis                0.000000
# inferior_frontal_gyrus_pars_opercularis                 0.069750
# precentral_gyrus                                        0.100541
# temporal_pole                                           0.000000
# superior_temporal_gyrus_anterior_division               0.000000
# superior_temporal_gyrus_posterior_division              0.000000
# middle_temporal_gyrus_anterior_division                 0.000000
# middle_temporal_gyrus_posterior_division                0.000000
# middle_temporal_gyrus_temporooccipital_part             0.080753
# inferior_temporal_gyrus_anterior_division               0.000000
# inferior_temporal_gyrus_posterior_division              0.000000
# inferior_temporal_gyrus_temporooccipital_part           0.048741
# postcentral_gyrus                                       0.121046
# superior_parietal_lobule                                0.121966
# supramarginal_gyrus_anterior_division                   0.130080
# supramarginal_gyrus_posterior_division                  0.111166
# angular_gyrus                                           0.098190
# lateral_occipital_cortex_superior_division              0.108485
# lateral_occipital_cortex_inferior_division              0.089058
# intracalcarine_cortex                                   0.000000
# frontal_medial_cortex                                   0.000000
# supplementary_motor_cortex                              0.086759
# subcallosal_cortex                                      0.000000
# paracingulate_gyrus                                     0.000000
# cingulate_gyrus_anterior_division                       0.000000
# cingulate_gyrus_posterior_division                      0.000000
# precuneous_cortex                                       0.055009
# cuneal_cortex                                           0.000000
# frontal_orbital_cortex                                  0.000000
# parahippocampal_gyrus_anterior_division                -0.059071
# parahippocampal_gyrus_posterior_division                0.000000
# lingual_gyrus                                           0.000000
# temporal_fusiform_cortex_anterior_division              0.000000
# temporal_fusiform_cortex_posterior_division             0.000000
# temporal_occipital_fusiform_cortex                      0.036589
# occipital_fusiform_gyrus                                0.048842
# frontal_operculum_cortex                                0.000000
# central_opercular_cortex                                0.000000
# parietal_operculum_cortex                               0.067683
# planum_polare                                           0.000000
# heschls_gyrus                                           0.000000
# planum_temporale                                        0.000000
# supracalcarine_cortex                                   0.000000
# occipital_pole                                          0.060822
#
#                                                MENTAL_STATE_UNDERSTANDING  \
# frontal_pole                                                     0.071520
# insular_cortex                                                   0.000000
# superior_frontal_gyrus                                           0.069782
# middle_frontal_gyrus                                             0.000000
# inferior_frontal_gyrus_pars_triangularis                         0.042695
# inferior_frontal_gyrus_pars_opercularis                          0.000000
# precentral_gyrus                                                 0.000000
# temporal_pole                                                    0.063323
# superior_temporal_gyrus_anterior_division                        0.065210
# superior_temporal_gyrus_posterior_division                       0.076751
# middle_temporal_gyrus_anterior_division                          0.100732
# middle_temporal_gyrus_posterior_division                         0.095910
# middle_temporal_gyrus_temporooccipital_part                      0.086316
# inferior_temporal_gyrus_anterior_division                        0.086413
# inferior_temporal_gyrus_posterior_division                       0.057489
# inferior_temporal_gyrus_temporooccipital_part                    0.000000
# postcentral_gyrus                                                0.000000
# superior_parietal_lobule                                         0.000000
# supramarginal_gyrus_anterior_division                            0.000000
# supramarginal_gyrus_posterior_division                           0.066662
# angular_gyrus                                                    0.077718
# lateral_occipital_cortex_superior_division                       0.062098
# lateral_occipital_cortex_inferior_division                       0.057845
# intracalcarine_cortex                                            0.000000
# frontal_medial_cortex                                            0.079929
# supplementary_motor_cortex                                       0.000000
# subcallosal_cortex                                               0.000000
# paracingulate_gyrus                                              0.061652
# cingulate_gyrus_anterior_division                                0.000000
# cingulate_gyrus_posterior_division                               0.066404
# precuneous_cortex                                                0.058226
# cuneal_cortex                                                    0.000000
# frontal_orbital_cortex                                           0.000000
# parahippocampal_gyrus_anterior_division                          0.000000
# parahippocampal_gyrus_posterior_division                         0.000000
# lingual_gyrus                                                    0.000000
# temporal_fusiform_cortex_anterior_division                       0.000000
# temporal_fusiform_cortex_posterior_division                      0.000000
# temporal_occipital_fusiform_cortex                               0.000000
# occipital_fusiform_gyrus                                         0.000000
# frontal_operculum_cortex                                         0.000000
# central_opercular_cortex                                         0.000000
# parietal_operculum_cortex                                        0.000000
# planum_polare                                                    0.000000
# heschls_gyrus                                                    0.000000
# planum_temporale                                                 0.000000
# supracalcarine_cortex                                            0.000000
# occipital_pole                                                   0.000000
#
#                                                 AROUSAL  CIRCADIAN_RHYTHMS  \
# frontal_pole                                   0.057698                0.0
# insular_cortex                                 0.090033                0.0
# superior_frontal_gyrus                         0.000000                0.0
# middle_frontal_gyrus                           0.000000                0.0
# inferior_frontal_gyrus_pars_triangularis       0.000000                0.0
# inferior_frontal_gyrus_pars_opercularis        0.000000                0.0
# precentral_gyrus                               0.000000                0.0
# temporal_pole                                  0.060925                0.0
# superior_temporal_gyrus_anterior_division      0.000000                0.0
# superior_temporal_gyrus_posterior_division     0.000000                0.0
# middle_temporal_gyrus_anterior_division        0.000000                0.0
# middle_temporal_gyrus_posterior_division       0.000000                0.0
# middle_temporal_gyrus_temporooccipital_part    0.000000                0.0
# inferior_temporal_gyrus_anterior_division      0.000000                0.0
# inferior_temporal_gyrus_posterior_division     0.000000                0.0
# inferior_temporal_gyrus_temporooccipital_part  0.000000                0.0
# postcentral_gyrus                              0.000000                0.0
# superior_parietal_lobule                      -0.048069                0.0
# supramarginal_gyrus_anterior_division          0.000000                0.0
# supramarginal_gyrus_posterior_division        -0.040032                0.0
# angular_gyrus                                  0.000000                0.0
# lateral_occipital_cortex_superior_division     0.000000                0.0
# lateral_occipital_cortex_inferior_division     0.000000                0.0
# intracalcarine_cortex                          0.000000                0.0
# frontal_medial_cortex                          0.078141                0.0
# supplementary_motor_cortex                     0.000000                0.0
# subcallosal_cortex                             0.066904                0.0
# paracingulate_gyrus                            0.057071                0.0
# cingulate_gyrus_anterior_division              0.064771                0.0
# cingulate_gyrus_posterior_division             0.041059                0.0
# precuneous_cortex                              0.000000                0.0
# cuneal_cortex                                  0.000000                0.0
# frontal_orbital_cortex                         0.065536                0.0
# parahippocampal_gyrus_anterior_division        0.105132                0.0
# parahippocampal_gyrus_posterior_division       0.000000                0.0
# lingual_gyrus                                  0.000000                0.0
# temporal_fusiform_cortex_anterior_division     0.000000                0.0
# temporal_fusiform_cortex_posterior_division    0.000000                0.0
# temporal_occipital_fusiform_cortex             0.000000                0.0
# occipital_fusiform_gyrus                       0.000000                0.0
# frontal_operculum_cortex                       0.040521                0.0
# central_opercular_cortex                       0.043193                0.0
# parietal_operculum_cortex                      0.000000                0.0
# planum_polare                                  0.000000                0.0
# heschls_gyrus                                  0.000000                0.0
# planum_temporale                               0.000000                0.0
# supracalcarine_cortex                          0.000000                0.0
# occipital_pole                                 0.000000                0.0
#
#                                                SLEEP_WAKEFULNESS
# frontal_pole                                            0.000000
# insular_cortex                                          0.000000
# superior_frontal_gyrus                                  0.000000
# middle_frontal_gyrus                                    0.000000
# inferior_frontal_gyrus_pars_triangularis                0.000000
# inferior_frontal_gyrus_pars_opercularis                -0.042251
# precentral_gyrus                                        0.000000
# temporal_pole                                           0.000000
# superior_temporal_gyrus_anterior_division               0.000000
# superior_temporal_gyrus_posterior_division              0.000000
# middle_temporal_gyrus_anterior_division                 0.000000
# middle_temporal_gyrus_posterior_division                0.000000
# middle_temporal_gyrus_temporooccipital_part             0.000000
# inferior_temporal_gyrus_anterior_division               0.000000
# inferior_temporal_gyrus_posterior_division              0.000000
# inferior_temporal_gyrus_temporooccipital_part           0.000000
# postcentral_gyrus                                       0.000000
# superior_parietal_lobule                                0.000000
# supramarginal_gyrus_anterior_division                   0.000000
# supramarginal_gyrus_posterior_division                  0.000000
# angular_gyrus                                           0.000000
# lateral_occipital_cortex_superior_division              0.000000
# lateral_occipital_cortex_inferior_division             -0.036593
# intracalcarine_cortex                                   0.000000
# frontal_medial_cortex                                   0.000000
# supplementary_motor_cortex                              0.000000
# subcallosal_cortex                                      0.000000
# paracingulate_gyrus                                     0.000000
# cingulate_gyrus_anterior_division                       0.000000
# cingulate_gyrus_posterior_division                      0.000000
# precuneous_cortex                                       0.000000
# cuneal_cortex                                           0.000000
# frontal_orbital_cortex                                  0.000000
# parahippocampal_gyrus_anterior_division                 0.000000
# parahippocampal_gyrus_posterior_division                0.000000
# lingual_gyrus                                           0.000000
# temporal_fusiform_cortex_anterior_division              0.000000
# temporal_fusiform_cortex_posterior_division             0.000000
# temporal_occipital_fusiform_cortex                      0.000000
# occipital_fusiform_gyrus                                0.000000
# frontal_operculum_cortex                                0.000000
# central_opercular_cortex                                0.000000
# parietal_operculum_cortex                               0.000000
# planum_polare                                           0.000000
# heschls_gyrus                                           0.000000
# planum_temporale                                        0.000000
# supracalcarine_cortex                                   0.000000
# occipital_pole                                          0.000000
#
# [48 rows x 42 columns]

# %%
construct = "ACUTE_THREAT"
R_con_rgb = [val2rgb[val] for val in R_left[construct]]
R_con_hex = [val2hex[val] for val in R_left[construct]]
# Out:
# ['dddcdc',
#  'f7bca1',
#  'dddcdc',
#  'aec9fc',
#  'dddcdc',
#  'bfd3f6',
#  'bcd2f7',
#  'f4c5ad',
#  'dddcdc',
#  'c6d6f1',
#  'dddcdc',
#  'c7d7f0',
#  'bfd3f6',
#  'dddcdc',
#  'dddcdc',
#  'bfd3f6',
#  'dddcdc',
#  'a3c2fe',
#  'c4d5f3',
#  'abc8fd',
#  'b2ccfb',
#  'a3c2fe',
#  'bbd1f8',
#  'dddcdc',
#  'f6bfa6',
#  'dddcdc',
#  'f6bea4',
#  'efcebd',
#  'f3c7b1',
#  'dddcdc',
#  'c5d6f2',
#  'dddcdc',
#  'f0cdbb',
#  'f7b194',
#  'dddcdc',
#  'dddcdc',
#  'dddcdc',
#  'dddcdc',
#  'dddcdc',
#  'c6d6f1',
#  'dddcdc',
#  'f1cdba',
#  'dddcdc',
#  'dddcdc',
#  'dddcdc',
#  'dddcdc',
#  'dddcdc',
#  'c1d4f4']

# %%
g_rgb2acr = [[R_con_hex[i], var2acr[var]] for i, var in enumerate(R_left.index)]
g_rgb2acr
# Out:
# [['dddcdc', 'FP'],
#  ['f7bca1', 'Ins'],
#  ['dddcdc', 'SFG'],
#  ['aec9fc', 'MFG'],
#  ['dddcdc', 'IFGpt'],
#  ['bfd3f6', 'IFGpo'],
#  ['bcd2f7', 'PrG'],
#  ['f4c5ad', 'TP'],
#  ['dddcdc', 'STGa'],
#  ['c6d6f1', 'STGp'],
#  ['dddcdc', 'MTGa'],
#  ['c7d7f0', 'MTGp'],
#  ['bfd3f6', 'MTGtp'],
#  ['dddcdc', 'ITGa'],
#  ['dddcdc', 'ITGp'],
#  ['bfd3f6', 'ITGtp'],
#  ['dddcdc', 'PoG'],
#  ['a3c2fe', 'SPL'],
#  ['c4d5f3', 'SmGa'],
#  ['abc8fd', 'SmGp'],
#  ['b2ccfb', 'AG'],
#  ['a3c2fe', 'LOCs'],
#  ['bbd1f8', 'LOCi'],
#  ['dddcdc', 'IcC'],
#  ['f6bfa6', 'FMC'],
#  ['dddcdc', 'SMC'],
#  ['f6bea4', 'ScC'],
#  ['efcebd', 'PcG'],
#  ['f3c7b1', 'CGa'],
#  ['dddcdc', 'CGp'],
#  ['c5d6f2', 'PcC'],
#  ['dddcdc', 'CC'],
#  ['f0cdbb', 'FOC'],
#  ['f7b194', 'PhGa'],
#  ['dddcdc', 'PaGp'],
#  ['dddcdc', 'LG'],
#  ['dddcdc', 'TFCa'],
#  ['dddcdc', 'TFCp'],
#  ['dddcdc', 'TOF'],
#  ['c6d6f1', 'OFG'],
#  ['dddcdc', 'FOpC'],
#  ['f1cdba', 'COpC'],
#  ['dddcdc', 'POpC'],
#  ['dddcdc', 'PP'],
#  ['dddcdc', 'H1\\/H2'],
#  ['dddcdc', 'PT'],
#  ['dddcdc', 'SccC'],
#  ['c1d4f4', 'OcP']]

# %%
def hex_to_rgb(hex):
    hex = hex.lstrip('#')
    hlen = len(hex)
    rgb = []
    for i in range(0, hlen, 2):
        rgb.append(int(hex[i:int(i+hlen/3)], 16))
    rgb = [int(round(val*255)) for val in rgb]
    return rgb

# %%
assigned = []
alphabet = "abcdefghijklmnopqrstuvwxyz"
g_rgb2acr = {}
g_label2rgb = []
for i, var in enumerate(R_left.index):
    if R_con_hex[i] not in assigned:
        g_rgb2acr[R_con_hex[i]] = var2acr[var]
        assigned.append(R_con_hex[i])
        g_label2rgb.append(R_con_rgb[i])
    else:
        hexcode = R_con_hex[i][:-1]
        if R_con_hex[i][-1].isdigit():
            hexcode += str(int(R_con_hex[i][-1]) + assigned.count(R_con_hex[i]))
        else:
            idx = alphabet.index(R_con_hex[i][-1])
            count = assigned.count(R_con_hex[i])
            if idx + count < 5:
                hexcode += alphabet[count + idx]
            else:
                hexcode += str(int(count))
        g_rgb2acr[hex] = var2acr[var]
        assigned.append(R_con_hex[i])
        rgb = hex_to_rgb(hexcode)
        g_label2rgb.append(rgb)
g_label2rgb
# Out:
# [[0.867, 0.864, 0.863],
#  [0.967, 0.736, 0.631],
#  [56355, 56100, 56355],
#  [0.683, 0.79, 0.99],
#  [56355, 56100, 56610],
#  [0.749, 0.828, 0.963],
#  [0.739, 0.823, 0.968],
#  [0.958, 0.771, 0.68],
#  [56355, 56100, 53805],
#  [0.777, 0.841, 0.946],
#  [56355, 56100, 54060],
#  [0.782, 0.843, 0.943],
#  [48705, 53805, 62985],
#  [56355, 56100, 54315],
#  [56355, 56100, 54570],
#  [48705, 53805, 63240],
#  [56355, 56100, 54825],
#  [0.641, 0.761, 0.998],
#  [0.768, 0.837, 0.952],
#  [0.673, 0.783, 0.992],
#  [0.698, 0.799, 0.985],
#  [41565, 49470, 61455],
#  [0.734, 0.82, 0.971],
#  [56355, 56100, 55080],
#  [0.964, 0.749, 0.649],
#  [56355, 56100, 55335],
#  [0.965, 0.745, 0.643],
#  [0.938, 0.809, 0.741],
#  [0.955, 0.779, 0.693],
#  [56355, 56100, 53295, 0],
#  [0.773, 0.839, 0.949],
#  [56355, 56100, 53295, 255],
#  [0.941, 0.806, 0.735],
#  [0.97, 0.696, 0.581],
#  [56355, 56100, 53295, 510],
#  [56355, 56100, 53295, 765],
#  [56355, 56100, 53295, 1020],
#  [56355, 56100, 53295, 1275],
#  [56355, 56100, 53295, 1530],
#  [50490, 54570, 61710],
#  [56355, 56100, 53295, 1785],
#  [0.943, 0.802, 0.729],
#  [56355, 56100, 53295, 2040],
#  [56355, 56100, 53295, 2295],
#  [56355, 56100, 53550, 0],
#  [56355, 56100, 53550, 255],
#  [56355, 56100, 53550, 510],
#  [0.759, 0.833, 0.958]]

# %%
g_label2rgb = R_con_rgb
R_con_rgb
# Out:
# [[0.867, 0.864, 0.863],
#  [0.967, 0.736, 0.631],
#  [0.867, 0.864, 0.863],
#  [0.683, 0.79, 0.99],
#  [0.867, 0.864, 0.863],
#  [0.749, 0.828, 0.963],
#  [0.739, 0.823, 0.968],
#  [0.958, 0.771, 0.68],
#  [0.867, 0.864, 0.863],
#  [0.777, 0.841, 0.946],
#  [0.867, 0.864, 0.863],
#  [0.782, 0.843, 0.943],
#  [0.749, 0.828, 0.963],
#  [0.867, 0.864, 0.863],
#  [0.867, 0.864, 0.863],
#  [0.749, 0.828, 0.963],
#  [0.867, 0.864, 0.863],
#  [0.641, 0.761, 0.998],
#  [0.768, 0.837, 0.952],
#  [0.673, 0.783, 0.992],
#  [0.698, 0.799, 0.985],
#  [0.641, 0.761, 0.998],
#  [0.734, 0.82, 0.971],
#  [0.867, 0.864, 0.863],
#  [0.964, 0.749, 0.649],
#  [0.867, 0.864, 0.863],
#  [0.965, 0.745, 0.643],
#  [0.938, 0.809, 0.741],
#  [0.955, 0.779, 0.693],
#  [0.867, 0.864, 0.863],
#  [0.773, 0.839, 0.949],
#  [0.867, 0.864, 0.863],
#  [0.941, 0.806, 0.735],
#  [0.97, 0.696, 0.581],
#  [0.867, 0.864, 0.863],
#  [0.867, 0.864, 0.863],
#  [0.867, 0.864, 0.863],
#  [0.867, 0.864, 0.863],
#  [0.867, 0.864, 0.863],
#  [0.777, 0.841, 0.946],
#  [0.867, 0.864, 0.863],
#  [0.943, 0.802, 0.729],
#  [0.867, 0.864, 0.863],
#  [0.867, 0.864, 0.863],
#  [0.867, 0.864, 0.863],
#  [0.867, 0.864, 0.863],
#  [0.867, 0.864, 0.863],
#  [0.759, 0.833, 0.958]]

# %%
g_value2rgb = []
for color in R_con_rgb:
    g_value2rgb.append([int(round(val*255)) for val in color])
print(len(g_value2rgb))
g_value2rgb
# Out:
# 48
# [[221, 220, 220],
#  [247, 188, 161],
#  [221, 220, 220],
#  [174, 201, 252],
#  [221, 220, 220],
#  [191, 211, 246],
#  [188, 210, 247],
#  [244, 197, 173],
#  [221, 220, 220],
#  [198, 214, 241],
#  [221, 220, 220],
#  [199, 215, 240],
#  [191, 211, 246],
#  [221, 220, 220],
#  [221, 220, 220],
#  [191, 211, 246],
#  [221, 220, 220],
#  [163, 194, 254],
#  [196, 213, 243],
#  [172, 200, 253],
#  [178, 204, 251],
#  [163, 194, 254],
#  [187, 209, 248],
#  [221, 220, 220],
#  [246, 191, 165],
#  [221, 220, 220],
#  [246, 190, 164],
#  [239, 206, 189],
#  [244, 199, 177],
#  [221, 220, 220],
#  [197, 214, 242],
#  [221, 220, 220],
#  [240, 206, 187],
#  [247, 177, 148],
#  [221, 220, 220],
#  [221, 220, 220],
#  [221, 220, 220],
#  [221, 220, 220],
#  [221, 220, 220],
#  [198, 214, 241],
#  [221, 220, 220],
#  [240, 205, 186],
#  [221, 220, 220],
#  [221, 220, 220],
#  [221, 220, 220],
#  [221, 220, 220],
#  [221, 220, 220],
#  [194, 212, 244]]

# %%
g_rgb2acr = {"FFFFFF":"[background]","D1D1D1":"FP","00FFFF":"Ins","007F7F":"SFG","00FF7F":"MFG","007F3F":"IFGpt","00FF00":"IFGpo","007F00":"PrG","7FFF00":"TP","3F7F00":"STGa","FFFF00":"STGp","7F7F00":"MTGa","FF7F00":"MTGp","7F3F00":"MTGtp","FF0000":"ITGa","7F0000":"ITGp","FF007F":"ITGtp","7F003F":"PoG","FF00FF":"SPL","7F007F":"SmGa","0055FF":"SmGp","002A7F":"AG","00FFD4":"LOCs","007F6A":"LOCi","00FF54":"IcC","007F2A":"FMC","2AFF00":"SMC","157F00":"ScC","A9FF00":"PcG","547F00":"CGa","FFD400":"CGp","7F6A00":"PcC","FF5400":"CC","7F2A00":"FOC","FF002A":"PhGa","7F0015":"PaGp","FF00A9":"LG","7F0054":"TFCa","AA00FF":"TFCp","55007F":"TOF","00AAFF":"OFG","00557F":"FOpC","00FFA9":"COpC","007F54":"POpC","00FF2A":"PP","007F15":"H1\/H2","54FF00":"PT","2A7F00":"SccC","D4FF00":"OcP","6A7F00":"[49]","FFA900":"[50]","7F5400":"[51]","FF2A00":"[52]","7F1500":"[53]","FF0054":"[54]","7F002A":"[55]","FF00D4":"[56]","7F006A":"[57]","5500FF":"[58]","2A007F":"[59]"}

# %%
g_acr2index = {"[background]":0,"FP":1,"Ins":2,"SFG":3,"MFG":4,"IFGpt":5,"IFGpo":6,"PrG":7,"TP":8,"STGa":9,"STGp":10,"MTGa":11,"MTGp":12,"MTGtp":13,"ITGa":14,"ITGp":15,"ITGtp":16,"PoG":17,"SPL":18,"SmGa":19,"SmGp":20,"AG":21,"LOCs":22,"LOCi":23,"IcC":24,"FMC":25,"SMC":26,"ScC":27,"PcG":28,"CGa":29,"CGp":30,"PcC":31,"CC":32,"FOC":33,"PhGa":34,"PaGp":35,"LG":36,"TFCa":37,"TFCp":38,"TOF":39,"OFG":40,"FOpC":41,"COpC":42,"POpC":43,"PP":44,"H1\/H2":45,"PT":46,"SccC":47,"OcP":48,"[49]":49,"[50]":50,"[51]":51,"[52]":52,"[53]":53,"[54]":54,"[55]":55,"[56]":56,"[57]":57,"[58]":58,"[59]":59}

# %%
g_label2rgb = [[1.0, 1.0, 1.0],[0.820,0.820,0.820],[0.000,1.000,1.000],[0.000,0.498,0.498],[0.000,1.000,0.498],[0.000,0.498,0.247],[0.000,1.000,0.000],[0.000,0.498,0.000],[0.498,1.000,0.000],[0.247,0.498,0.000],[1.000,1.000,0.000],[0.498,0.498,0.000],[1.000,0.498,0.000],[0.498,0.247,0.000],[1.000,0.000,0.000],[0.498,0.000,0.000],[1.000,0.000,0.498],[0.498,0.000,0.247],[1.000,0.000,1.000],[0.498,0.000,0.498],[0.000,0.333,1.000],[0.000,0.165,0.498],[0.000,1.000,0.831],[0.000,0.498,0.416],[0.000,1.000,0.329],[0.000,0.498,0.165],[0.165,1.000,0.000],[0.082,0.498,0.000],[0.663,1.000,0.000],[0.329,0.498,0.000],[1.000,0.831,0.000],[0.498,0.416,0.000],[1.000,0.329,0.000],[0.498,0.165,0.000],[1.000,0.000,0.165],[0.498,0.000,0.082],[1.000,0.000,0.663],[0.498,0.000,0.329],[0.667,0.000,1.000],[0.333,0.000,0.498],[0.000,0.667,1.000],[0.000,0.333,0.498],[0.000,1.000,0.663],[0.000,0.498,0.329],[0.000,1.000,0.165],[0.000,0.498,0.082],[0.329,1.000,0.000],[0.165,0.498,0.000],[0.831,1.000,0.000],[0.416,0.498,0.000],[1.000,0.663,0.000],[0.498,0.329,0.000],[1.000,0.165,0.000],[0.498,0.082,0.000],[1.000,0.000,0.329],[0.498,0.000,0.165],[1.000,0.000,0.831],[0.498,0.000,0.416],[0.333,0.000,1.000],[0.165,0.000,0.498]]

# %%
g_value2rgb[47]
# Out:
# [194, 212, 244]

# %%
g_value2rgb = [
[1,1,1],
[209,209,209],
[0,0,6],
[1,0,7],
[1,1,9],
[1,1,11],
[2,1,14],
[2,2,16],
[3,2,18],
[4,3,20],
[4,3,22],
[5,4,24],
[6,4,27],
[7,5,29],
[8,6,31],
[9,6,33],
[10,7,36],
[12,7,38],
[13,8,40],
[14,8,43],
[15,9,45],
[16,9,47],
[18,10,50],
[19,10,52],
[20,11,55],
[22,11,57],
[23,11,59],
[25,11,62],
[26,12,64],
[28,12,67],
[29,12,69],
[31,12,72],
[33,12,74],
[34,11,76],
[36,11,78],
[38,11,81],
[39,11,83],
[41,11,85],
[43,10,87],
[45,10,89],
[46,10,90],
[48,10,92],
[50,9,94],
[52,9,95],
[54,9,96],
[55,9,98],
[57,9,99],
[59,9,100],
[60,9,101],
[62,9,102],
[64,9,103],
[66,9,104],
[67,10,104],
[69,10,105],
[71,10,106],
[72,11,106],
[74,11,107],
[76,12,107],
[77,12,108],
[79,13,108],
[80,13,108],
[82,14,109],
[84,14,109],
[85,15,109],
[87,15,109],
[89,16,110],
[90,17,110],
[92,17,110],
[93,18,110],
[95,18,110],
[97,19,110],
[98,20,110],
[100,20,110],
[101,21,110],
[103,21,110],
[104,22,110],
[106,23,110],
[108,23,110],
[109,24,110],
[111,24,110],
[112,25,110],
[114,26,110],
[116,26,110],
[117,27,110],
[119,27,109],
[120,28,109],
[122,28,109],
[124,29,109],
[125,29,108],
[127,30,108],
[128,31,108],
[130,31,108],
[132,32,107],
[133,32,107],
[135,33,107],
[136,33,106],
[138,34,106],
[140,35,105],
[141,35,105],
[143,36,104],
[144,36,104],
[146,37,104],
[148,37,103],
[149,38,103],
[151,39,102],
[152,39,101],
[154,40,101],
[155,40,100],
[157,41,100],
[159,42,99],
[160,42,98],
[162,43,98],
[163,43,97],
[165,44,96],
[167,45,96],
[168,45,95],
[170,46,94],
[171,47,93],
[173,47,93],
[174,48,92],
[176,49,91],
[177,49,90],
[179,50,89],
[180,51,89],
[182,52,88],
[183,52,87],
[185,53,86],
[186,54,85],
[188,55,84],
[189,56,83],
[191,56,82],
[192,57,81],
[194,58,80],
[195,59,79],
[197,60,78],
[198,61,77],
[199,62,76],
[201,63,75],
[202,64,74],
[203,65,73],
[205,66,72],
[206,67,71],
[207,68,70],
[209,69,69],
[210,70,68],
[211,71,67],
[213,72,65],
[214,73,64],
[215,74,63],
[216,76,62],
[217,77,61],
[219,78,60],
[220,79,59],
[221,81,57],
[222,82,56],
[223,83,55],
[224,85,54],
[225,86,53],
[226,87,51],
[227,89,50],
[228,90,49],
[229,91,48],
[230,93,47],
[231,94,45],
[232,96,44],
[233,97,43],
[234,99,42],
[235,100,40],
[236,102,39],
[237,103,38],
[237,105,37],
[238,106,35],
[239,108,34],
[240,110,33],
[241,111,32],
[241,113,30],
[242,114,29],
[243,116,28],
[243,118,26],
[244,119,25],
[244,121,24],
[245,123,22],
[246,125,21],
[246,126,20],
[247,128,18],
[247,130,17],
[248,132,16],
[248,133,14],
[248,135,13],
[249,137,12],
[249,139,11],
[250,141,9],
[250,142,8],
[250,144,8],
[251,146,7],
[251,148,6],
[251,150,6],
[251,152,6],
[252,153,6],
[252,155,6],
[252,157,6],
[252,159,7],
[252,161,7],
[252,163,8],
[252,165,10],
[252,167,11],
[252,169,13],
[252,170,14],
[252,172,16],
[252,174,18],
[252,176,20],
[252,178,22],
[252,180,24],
[252,182,26],
[252,184,28],
[252,186,30],
[251,188,33],
[251,190,35],
[251,192,37],
[251,194,40],
[250,196,42],
[250,198,45],
[250,200,47],
[249,202,50],
[249,204,52],
[249,206,55],
[248,208,58],
[248,210,61],
[247,212,63],
[247,214,66],
[246,216,69],
[246,217,73],
[245,219,76],
[245,221,79],
[244,223,82],
[244,225,86],
[244,227,89],
[243,229,93],
[243,231,97],
[242,233,101],
[242,234,105],
[242,236,109],
[242,238,113],
[242,239,117],
[242,241,121],
[242,243,125],
[243,244,130],
[243,245,134],
[244,247,138],
[245,248,142],
[246,249,146],
[247,251,150],
[248,252,154],
[249,253,157],
[251,254,161],
[253,255,165]
]
len(g_value2rgb)
# Out:
# 256

# %%
len(R_con_rgb)
# Out:
# 48

# %%
color = ",".join([str(val) for val in list(np.array(R_con_rgb).flatten())])
color
# Out:
# '0.867,0.864,0.863,0.967,0.736,0.631,0.867,0.864,0.863,0.683,0.79,0.99,0.867,0.864,0.863,0.749,0.828,0.963,0.739,0.823,0.968,0.958,0.771,0.68,0.867,0.864,0.863,0.777,0.841,0.946,0.867,0.864,0.863,0.782,0.843,0.943,0.749,0.828,0.963,0.867,0.864,0.863,0.867,0.864,0.863,0.749,0.828,0.963,0.867,0.864,0.863,0.641,0.761,0.998,0.768,0.837,0.952,0.673,0.783,0.992,0.698,0.799,0.985,0.641,0.761,0.998,0.734,0.82,0.971,0.867,0.864,0.863,0.964,0.749,0.649,0.867,0.864,0.863,0.965,0.745,0.643,0.938,0.809,0.741,0.955,0.779,0.693,0.867,0.864,0.863,0.773,0.839,0.949,0.867,0.864,0.863,0.941,0.806,0.735,0.97,0.696,0.581,0.867,0.864,0.863,0.867,0.864,0.863,0.867,0.864,0.863,0.867,0.864,0.863,0.867,0.864,0.863,0.777,0.841,0.946,0.867,0.864,0.863,0.943,0.802,0.729,0.867,0.864,0.863,0.867,0.864,0.863,0.867,0.864,0.863,0.867,0.864,0.863,0.867,0.864,0.863,0.759,0.833,0.958'

# %%
color="0.9,0.9,0.9,0.820,0.820,0.820,0.000,1.000,1.000,0.000,0.498,0.498,0.000,1.000,0.498,0.000,0.498,0.247,0.000,1.000,0.000,0.000,0.498,0.000,0.498,1.000,0.000,0.247,0.498,0.000,1.000,1.000,0.000,0.498,0.498,0.000,1.000,0.498,0.000,0.498,0.247,0.000,1.000,0.000,0.000,0.498,0.000,0.000,1.000,0.000,0.498,0.498,0.000,0.247,1.000,0.000,1.000,0.498,0.000,0.498,0.000,0.333,1.000,0.000,0.165,0.498,0.000,1.000,0.831,0.000,0.498,0.416,0.000,1.000,0.329,0.000,0.498,0.165,0.165,1.000,0.000,0.082,0.498,0.000,0.663,1.000,0.000,0.329,0.498,0.000,1.000,0.831,0.000,0.498,0.416,0.000,1.000,0.329,0.000,0.498,0.165,0.000,1.000,0.000,0.165,0.498,0.000,0.082,1.000,0.000,0.663,0.498,0.000,0.329,0.667,0.000,1.000,0.333,0.000,0.498,0.000,0.667,1.000,0.000,0.333,0.498,0.000,1.000,0.663,0.000,0.498,0.329,0.000,1.000,0.165,0.000,0.498,0.082,0.329,1.000,0.000,0.165,0.498,0.000,0.831,1.000,0.000,0.416,0.498,0.000,1.000,0.663,0.000,0.498,0.329,0.000,1.000,0.165,0.000,0.498,0.082,0.000,1.000,0.000,0.329,0.498,0.000,0.165,1.000,0.000,0.831,0.498,0.000,0.416,0.333,0.000,1.000,0.165,0.000,0.498"

# %%
color.split(",")[1+(48*3)]
# Out:
# '1.000'
